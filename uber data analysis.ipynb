# %% [markdown]
# Description:
# The project is about on world's largest taxi company Uber inc. In this project, we're looking to predict the fare for their future transactional cases. Uber delivers service to lakhs of customers daily. Now it becomes really important to manage their data properly to come up with new business ideas to get best results. Eventually, it becomes really important to estimate the fare prices accurately.
#
# The datset contains the following fields:
# key - a unique identifier for each trip
# fare_amount - the cost of each trip in usd
# pickup_datetime - date and time when the meter was engaged
# passenger_count - the number of passengers in the vehicle (driver entered value)
# pickup_longitude - the longitude where the meter was engaged
# pickup_latitude - the latitude where the meter was engaged
# dropoff_longitude - the longitude where the meter was disengaged
# dropoff_latitude - the latitude where the meter was disengaged
# Acknowledgement:
# The dataset is referred from Kaggle.
#
# Objective:
# Understand the Dataset & cleanup (if required).
# Build Regression models to predict the fare price of uber ride.
# Also evaluate the models & compare thier respective scores like R2, RMSE, etc

# %%
import  pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
import math
from scipy import stats

# %%
df=pd.read_csv("uber.csv")
df.head()
# Out:
#    Unnamed: 0                            key  fare_amount  \
# 0    24238194    2015-05-07 19:52:06.0000003          7.5
# 1    27835199    2009-07-17 20:04:56.0000002          7.7
# 2    44984355   2009-08-24 21:45:00.00000061         12.9
# 3    25894730    2009-06-26 08:22:21.0000001          5.3
# 4    17610152  2014-08-28 17:47:00.000000188         16.0
#
#            pickup_datetime  pickup_longitude  pickup_latitude  \
# 0  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.999512         40.723217                1
# 1         -73.994710         40.750325                1
# 2         -73.962565         40.772647                1
# 3         -73.965316         40.803349                3
# 4         -73.973082         40.761247                5

# %%
df.tail()
# Out:
#         Unnamed: 0                           key  fare_amount  \
# 199995    42598914  2012-10-28 10:49:00.00000053          3.0
# 199996    16382965   2014-03-14 01:09:00.0000008          7.5
# 199997    27804658  2009-06-29 00:42:00.00000078         30.9
# 199998    20259894   2015-05-20 14:56:25.0000004         14.5
# 199999    11951496  2010-05-15 04:08:00.00000076         14.1
#
#                 pickup_datetime  pickup_longitude  pickup_latitude  \
# 199995  2012-10-28 10:49:00 UTC        -73.987042        40.739367
# 199996  2014-03-14 01:09:00 UTC        -73.984722        40.736837
# 199997  2009-06-29 00:42:00 UTC        -73.986017        40.756487
# 199998  2015-05-20 14:56:25 UTC        -73.997124        40.725452
# 199999  2010-05-15 04:08:00 UTC        -73.984395        40.720077
#
#         dropoff_longitude  dropoff_latitude  passenger_count
# 199995         -73.986525         40.740297                1
# 199996         -74.006672         40.739620                1
# 199997         -73.858957         40.692588                2
# 199998         -73.983215         40.695415                1
# 199999         -73.985508         40.768793                1

# %%
df.shape
# Out:
# (200000, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         200000 non-null  int64
#  1   key                200000 non-null  object
#  2   fare_amount        200000 non-null  float64
#  3   pickup_datetime    200000 non-null  object
#  4   pickup_longitude   200000 non-null  float64
#  5   pickup_latitude    200000 non-null  float64
#  6   dropoff_longitude  199999 non-null  float64
#  7   dropoff_latitude   199999 non-null  float64
#  8   passenger_count    200000 non-null  int64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 13.7+ MB

# %% [markdown]
# # Missing Value Check

# %%
df.isna().sum()
# Out:
# Unnamed: 0           0
# key                  0
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    1
# dropoff_latitude     1
# passenger_count      0
# dtype: int64

# %% [markdown]
# # Lets see the data statistics to check for outliers in features

# %%
df.describe(include='all').transpose()
# Out:
#                       count  unique                          top freq  \
# Unnamed: 0         200000.0     NaN                          NaN  NaN
# key                  200000  200000  2015-05-07 19:52:06.0000003    1
# fare_amount        200000.0     NaN                          NaN  NaN
# pickup_datetime      200000  196629      2014-04-13 18:19:00 UTC    4
# pickup_longitude   200000.0     NaN                          NaN  NaN
# pickup_latitude    200000.0     NaN                          NaN  NaN
# dropoff_longitude  199999.0     NaN                          NaN  NaN
# dropoff_latitude   199999.0     NaN                          NaN  NaN
# passenger_count    200000.0     NaN                          NaN  NaN
#
#                              mean              std         min          25%  \
# Unnamed: 0         27712503.68235  16013822.212829         1.0  13825346.25
# key                           NaN              NaN         NaN          NaN
# fare_amount             11.359955         9.901776       -52.0          6.0
# pickup_datetime               NaN              NaN         NaN          NaN
# pickup_longitude       -72.527638        11.437787 -1340.64841   -73.992065
# pickup_latitude         39.935885         7.720539  -74.015515    40.734796
# dropoff_longitude      -72.525292        13.117408  -3356.6663   -73.991407
# dropoff_latitude         39.92389         6.794829 -881.985513    40.733823
# passenger_count          1.684535         1.385997         0.0          1.0
#
#                           50%          75%          max
# Unnamed: 0         27745495.0  41555300.75   55423567.0
# key                       NaN          NaN          NaN
# fare_amount               8.5         12.5        499.0
# pickup_datetime           NaN          NaN          NaN
# pickup_longitude   -73.981823   -73.967154    57.418457
# pickup_latitude     40.752592    40.767158  1644.421482
# dropoff_longitude  -73.980093   -73.963658  1153.572603
# dropoff_latitude    40.753042    40.768001   872.697628
# passenger_count           1.0          2.0        208.0

# %% [markdown]
# # outliers are not present in dropoff_longitude and dropoff_latitude hence we can replace the nan vlaue with the mean of it

# %%
df.replace(np.nan,df.dropoff_longitude.mean(),inplace=True)
df.replace(np.nan,df.dropoff_latitude.mean(),inplace=True)

# %% [markdown]
# # null values are removed

# %%
df.isna().sum()
# Out:
# Unnamed: 0           0
# key                  0
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    0
# dropoff_latitude     0
# passenger_count      0
# dtype: int64

# %%
df.nunique()
# Out:
# Unnamed: 0           200000
# key                  200000
# fare_amount            1244
# pickup_datetime      196629
# pickup_longitude      71066
# pickup_latitude       83835
# dropoff_longitude     76895
# dropoff_latitude      90586
# passenger_count           8
# dtype: int64

# %% [markdown]
# # all the values of key and unnamed are unique hence we can drop this column as it wont give any meaningful insight

# %%
df.drop(columns=['key','Unnamed: 0'],inplace=True)

# %%
df.pickup_datetime = pd.to_datetime(df['pickup_datetime'])


df['Year'] = df['pickup_datetime'].dt.year
df['Month'] = df['pickup_datetime'].dt.month
df['Day'] = df['pickup_datetime'].dt.day
df['Hour'] = df['pickup_datetime'].dt.hour
df['Day_Name'] = df['pickup_datetime'].dt.day_name()

# %% [markdown]
# # As i have extracted the required information from the pickup_datetime from data i can drop this column

# %%
df.drop(columns=['pickup_datetime'],inplace=True)

# %%
df.head(2)
# Out:
#    fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0          7.5        -73.999817        40.738354         -73.999512
# 1          7.7        -73.994355        40.728225         -73.994710
#
#    dropoff_latitude  passenger_count  Year  Month  Day  Hour  Day_Name
# 0         40.723217                1  2015      5    7    19  Thursday
# 1         40.750325                1  2009      7   17    20    Friday

# %% [markdown]
# # lets calculate the distance between two points to getter better insights abouts the fare_amount

# %%
def distance(long1, lat1, long2, lat2):

    long1, lat1, long2, lat2 = map(np.radians, [long1, lat1, long2, lat2])

    dlong = long2 - long1
    dlat = lat2 - lat1

    a = np.sin(dlat/2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlong/2.0)**2

    c = 2 * np.arcsin(np.sqrt(a))
    km = 6367 * c
    return km

df['distance'] =distance( df["pickup_longitude"], df["pickup_latitude"], df["dropoff_longitude"], df["dropoff_latitude"])

df.head()
# Out:
#    fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0          7.5        -73.999817        40.738354         -73.999512
# 1          7.7        -73.994355        40.728225         -73.994710
# 2         12.9        -74.005043        40.740770         -73.962565
# 3          5.3        -73.976124        40.790844         -73.965316
# 4         16.0        -73.925023        40.744085         -73.973082
#
#    dropoff_latitude  passenger_count  Year  Month  Day  Hour  Day_Name  \
# 0         40.723217                1  2015      5    7    19  Thursday
# 1         40.750325                1  2009      7   17    20    Friday
# 2         40.772647                1  2009      8   24    21    Monday
# 3         40.803349                3  2009      6   26     8    Friday
# 4         40.761247                5  2014      8   28    17  Thursday
#
#    distance
# 0  1.682266
# 1  2.456047
# 2  5.033215
# 3  1.660640
# 4  4.472640

# %% [markdown]
# # Lets round off the values to two decimal places to make the feature values more readable

# %%
df['distance']=round(df['distance'],2)

# %%
df['pickup_longitude']=round(df['pickup_longitude'],2)

# %%
df['pickup_latitude']=round(df['pickup_latitude'],2)

# %%
df['dropoff_longitude']=round(df['dropoff_longitude'],2)

# %%
df['dropoff_latitude']=round(df['dropoff_latitude'],2)

# %%
df.head()
# Out:
#    fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0          7.5            -74.00            40.74             -74.00
# 1          7.7            -73.99            40.73             -73.99
# 2         12.9            -74.01            40.74             -73.96
# 3          5.3            -73.98            40.79             -73.97
# 4         16.0            -73.93            40.74             -73.97
#
#    dropoff_latitude  passenger_count  Year  Month  Day  Hour  Day_Name  \
# 0             40.72                1  2015      5    7    19  Thursday
# 1             40.75                1  2009      7   17    20    Friday
# 2             40.77                1  2009      8   24    21    Monday
# 3             40.80                3  2009      6   26     8    Friday
# 4             40.76                5  2014      8   28    17  Thursday
#
#    distance
# 0      1.68
# 1      2.46
# 2      5.03
# 3      1.66
# 4      4.47

# %% [markdown]
# # Lets Check the no of passengengers used the uber car per ride

# %%
sns.countplot(x='passenger_count',data=df)
# Out:
# <AxesSubplot:xlabel='passenger_count', ylabel='count'>

# %% [markdown]
# # Here Mostly Single person used the uber car,that can be for personal use or office work

# %%
df['passenger_count'].value_counts()*100/len(df)
# Out:
# 1      69.2125
# 2      14.7140
# 5       7.0045
# 3       4.4405
# 4       2.1380
# 6       2.1355
# 0       0.3545
# 208     0.0005
# Name: passenger_count, dtype: float64

# %% [markdown]
# # dropping the passenger count which dosent contribute much to our analysis and also can act as an outlier and make the model biased

# %%
df['passenger_count'].replace([0,208,4,6],[np.nan,np.nan,np.nan,np.nan],inplace=True)

# %%
df.dropna(axis=0,how='any',thresh=None,subset='passenger_count',inplace=True)

# %%
df.isna().sum()
# Out:
# fare_amount          0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    0
# dropoff_latitude     0
# passenger_count      0
# Year                 0
# Month                0
# Day                  0
# Hour                 0
# Day_Name             0
# distance             0
# dtype: int64

# %% [markdown]
# # Lets combine some Features in  pca components to reduce the no of features and also to retrive some useful information

# %%
from sklearn.decomposition import PCA

# %%
pca_comp= PCA(n_components=1)
df["final_pickup_point"] = pca_comp.fit_transform(df[["pickup_longitude","pickup_latitude"]])
df.drop(columns=["pickup_longitude","pickup_latitude"],inplace=True)

# %%
df["final_dropoff_point"] = pca_comp.fit_transform(df[["dropoff_longitude","dropoff_latitude"]])
df.drop(columns=["dropoff_longitude","dropoff_latitude"],inplace=True)

# %%
df["final_pickup_point"]=round(df["final_pickup_point"],2)

# %%
df['final_dropoff_point']=round(df["final_dropoff_point"],2)

# %%
df.describe(include='all').transpose()
# Out:
#                         count unique     top   freq         mean         std  \
# fare_amount          190743.0    NaN     NaN    NaN    11.342801    9.902894
# passenger_count      190743.0    NaN     NaN    NaN     1.541178    1.105786
# Year                 190743.0    NaN     NaN    NaN  2011.718212    1.859177
# Month                190743.0    NaN     NaN    NaN     6.277158    3.437575
# Day                  190743.0    NaN     NaN    NaN    15.701142    8.686653
# Hour                 190743.0    NaN     NaN    NaN    13.485334    6.507689
# Day_Name               190743      7  Friday  29476          NaN         NaN
# distance             190743.0    NaN     NaN    NaN    20.437089  378.479333
# final_pickup_point   190743.0    NaN     NaN    NaN     0.000052   13.278057
# final_dropoff_point  190743.0    NaN     NaN    NaN    -0.000149   14.647211
#
#                          min     25%     50%     75%       max
# fare_amount            -52.0     6.0     8.5    12.5     499.0
# passenger_count          1.0     1.0     1.0     2.0       5.0
# Year                  2009.0  2010.0  2012.0  2013.0    2015.0
# Month                    1.0     3.0     6.0     9.0      12.0
# Day                      1.0     8.0    16.0    23.0      31.0
# Hour                     0.0     9.0    14.0    19.0      23.0
# Day_Name                 NaN     NaN     NaN     NaN       NaN
# distance                 0.0    1.21    2.12    3.87  16398.94
# final_pickup_point   -156.38    1.65    1.66    1.67   1923.94
# final_dropoff_point -1505.48    1.66    1.66    1.67   3318.41

# %% [markdown]
# # from the above statistic comapring mean and median we can say that there are outliers in the column fare_amount and distance

# %% [markdown]
# # Lets remove the outliers using box plot

# %%
plt.figure(figsize=(12,8))
pc_cols=['fare_amount','distance']
p=0
for j in range(len(pc_cols)):
    var=pc_cols[j]
    p=p+1
    plt.subplot(2, 2, p)
    plt.title(var+' With Outliers')
    plt.boxplot(df[var])
    Q1 = df[var].quantile(0.05)
    Q3 = df[var].quantile(0.90)
    IQR = Q3 - Q1
    df = df[(df[var] >= Q1 - 1.5*IQR) & (df[var] <= Q3 + 1.5*IQR)]
    p=p+1
    plt.subplot(2, 2, p)
    plt.title(var+' After Outlier Treatment')
    plt.boxplot(df[var])

# %%
plt.rcParams["figure.figsize"] = (25,5)
sns.distplot(df['fare_amount'],label='fare_amount')
# Out:
# <AxesSubplot:xlabel='fare_amount', ylabel='Density'>

# %%
df['fare_amount'].skew()
# Out:
# 2.086233636686639

# %%
df['fare_amount'].kurt()
# Out:
# 5.277360918441104

# %%
df.shape
# Out:
# (185087, 10)

# %% [markdown]
# # Even after removing the outliers we can see the dat is highly skewes and leptokurtic lets remove some outliers with basic maths

# %% [markdown]
# # calculation for fare_amount feature

# %%
len(df[df['fare_amount']>40])
# Out:
# 739

# %%
df=df[df['fare_amount']<40]

# %%
df.shape
# Out:
# (184315, 10)

# %% [markdown]
# # calculation for distance feature

# %%
plt.rcParams["figure.figsize"] = (25,5)
sns.distplot(df['distance'],label='distance')
# Out:
# <AxesSubplot:xlabel='distance', ylabel='Density'>

# %%
df['distance'].skew()
# Out:
# 1.836841337683558

# %%
df['distance'].kurt()
# Out:
# 3.8574012753767235

# %%
df.shape
# Out:
# (184315, 10)

# %% [markdown]
# # still we are left with outliers as data is skewed and leptokurtic lets try to remove outliers using knn

# %%
from sklearn.neighbors import NearestNeighbors

# %%
data= df[["fare_amount", "distance"]]

# %%
plt.scatter(data["fare_amount"], data["distance"])

# %%
# create arrays
X = data.values

# %%
# instantiate model
nbrs = NearestNeighbors(n_neighbors = 3)

# %%
# fit model
nbrs.fit(X)
# Out:
# NearestNeighbors(n_neighbors=3)

# %% [markdown]
# # Now that we have fitted the model, it’s time to extract model outputs—(a) distances between data points
# # and (b) associated index values — that can be used for detecting anomalies.

# %%
# distances and indexes of k-neaighbors from model outputs
distances, indexes = nbrs.kneighbors(X)

# %% [markdown]
# # plot mean of k-distances of each observation

# %%
plt.plot(distances.mean(axis =1))

# %% [markdown]
# # visually determined cutoff values > 0 and using hit and trial method i have selected 0.09 as the best for now

# %%
outlier_index = np.where(distances.mean(axis = 1)>0.09)
outlier_index
# Out:
# (array([    81,    186,    209, ..., 183933, 183959, 184031], dtype=int64),)

# %%
outlier_values = data.iloc[outlier_index]
outlier_values
# Out:
#         fare_amount  distance
# 87             4.50      6.90
# 196           24.00     13.94
# 221           29.50      5.09
# 487           33.70     11.79
# 594           22.50     14.12
# ...             ...       ...
# 199395        28.80      1.64
# 199494        38.50     13.03
# 199580        29.50      4.82
# 199607         5.30      4.84
# 199690        31.83      8.46
#
# [1711 rows x 2 columns]

# %%
outlier_values['fare_amount_outlier']=outlier_values['fare_amount']
outlier_values['distance_outlier']=outlier_values['distance']
outlier_values.drop(columns=['fare_amount','distance'])
# Out:
#         fare_amount_outlier  distance_outlier
# 87                     4.50              6.90
# 196                   24.00             13.94
# 221                   29.50              5.09
# 487                   33.70             11.79
# 594                   22.50             14.12
# ...                     ...               ...
# 199395                28.80              1.64
# 199494                38.50             13.03
# 199580                29.50              4.82
# 199607                 5.30              4.84
# 199690                31.83              8.46
#
# [1711 rows x 2 columns]

# %% [markdown]
# # Outlier values are reprensented in red colour

# %%
# plot data
plt.scatter(data['fare_amount'], data["distance"],color = "b", s = 65)
# plot outlier values
plt.scatter(outlier_values["fare_amount_outlier"], outlier_values["distance_outlier"], color = "r")

# %%
df=pd.merge(df,outlier_values,how='left')
df
# Out:
#         fare_amount  passenger_count  Year  Month  Day  Hour   Day_Name  \
# 0               7.5              1.0  2015      5    7    19   Thursday
# 1               7.7              1.0  2009      7   17    20     Friday
# 2              12.9              1.0  2009      8   24    21     Monday
# 3               5.3              3.0  2009      6   26     8     Friday
# 4              16.0              5.0  2014      8   28    17   Thursday
# ...             ...              ...   ...    ...  ...   ...        ...
# 184310          3.0              1.0  2012     10   28    10     Sunday
# 184311          7.5              1.0  2014      3   14     1     Friday
# 184312         30.9              2.0  2009      6   29     0     Monday
# 184313         14.5              1.0  2015      5   20    14  Wednesday
# 184314         14.1              1.0  2010      5   15     4   Saturday
#
#         distance  final_pickup_point  final_dropoff_point  \
# 0           1.68                1.67                 1.67
# 1           2.46                1.66                 1.67
# 2           5.03                1.68                 1.66
# 3           1.66                1.68                 1.68
# 4           4.47                1.61                 1.66
# ...          ...                 ...                  ...
# 184310      0.11                1.66                 1.67
# 184311      1.87                1.65                 1.69
# 184312     12.84                1.67                 1.53
# 184313      3.54                1.66                 1.64
# 184314      5.41                1.64                 1.68
#
#         fare_amount_outlier  distance_outlier
# 0                       NaN               NaN
# 1                       NaN               NaN
# 2                       NaN               NaN
# 3                       NaN               NaN
# 4                       NaN               NaN
# ...                     ...               ...
# 184310                  NaN               NaN
# 184311                  NaN               NaN
# 184312                  NaN               NaN
# 184313                  NaN               NaN
# 184314                  NaN               NaN
#
# [184315 rows x 12 columns]

# %%
df['fare_amount_outlier'].replace(np.nan,0,inplace=True)
for i in df['fare_amount_outlier']:
    if i!=0:
        df['fare_amount_outlier'].replace(i,np.nan,inplace=True)
df.dropna(axis=0,how='any',thresh=None,subset='fare_amount_outlier',inplace=True)

# %%
df.drop(columns=['fare_amount_outlier','distance_outlier'],inplace=True)

# %%
df.head(2)
# Out:
#    fare_amount  passenger_count  Year  Month  Day  Hour  Day_Name  distance  \
# 0          7.5              1.0  2015      5    7    19  Thursday      1.68
# 1          7.7              1.0  2009      7   17    20    Friday      2.46
#
#    final_pickup_point  final_dropoff_point
# 0                1.67                 1.67
# 1                1.66                 1.67

# %%
plt.rcParams["figure.figsize"] = (25,5)
sns.distplot(df['fare_amount'],label='fare_amount')
# Out:
# <AxesSubplot:xlabel='fare_amount', ylabel='Density'>

# %%
plt.rcParams["figure.figsize"] = (25,5)
sns.distplot(df['distance'],label='distance')
# Out:
# <AxesSubplot:xlabel='distance', ylabel='Density'>

# %% [markdown]
# # Lets CHeck the correlation of target variable with independent features

# %%
correlation = df.corr()
correlation['fare_amount']
# Out:
# fare_amount            1.000000
# passenger_count        0.004033
# Year                   0.132849
# Month                  0.030226
# Day                    0.003684
# Hour                  -0.021237
# distance               0.862341
# final_pickup_point    -0.001269
# final_dropoff_point   -0.001450
# Name: fare_amount, dtype: float64

# %% [markdown]
# # here distance is highly correlated with target and its the fact with distance fare rises or vice versa

# %%
plt.figure(figsize=(12,7))

sns.heatmap(correlation,annot=True,cmap='Accent')
# Out:
# <AxesSubplot:>

# %%
#df["Day_Name"].replace(['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'],[1,2,3,4,5,6,7],inplace=True)

# %% [markdown]
# # Lets convert the categorical column to numerical for further analysis

# %%
from sklearn.preprocessing import OneHotEncoder 
#since here we have a problem of multicollinearity we will drop
ohe = OneHotEncoder(dtype=np.int32) #Initialising

# %%
df['Day_Name']=ohe.fit_transform(df[['Day_Name']]).toarray()

# %% [markdown]
# # Lets Separate Target variable from indepentt features for analysis

# %%
x=df.drop(columns=['fare_amount'])
x.head(2)
# Out:
#    passenger_count  Year  Month  Day  Hour  Day_Name  distance  \
# 0              1.0  2015      5    7    19         0      1.68
# 1              1.0  2009      7   17    20         1      2.46
#
#    final_pickup_point  final_dropoff_point
# 0                1.67                 1.67
# 1                1.66                 1.67

# %%
x.isna().sum()
# Out:
# passenger_count        0
# Year                   0
# Month                  0
# Day                    0
# Hour                   0
# Day_Name               0
# distance               0
# final_pickup_point     0
# final_dropoff_point    0
# dtype: int64

# %% [markdown]
# # Checking for muticollinearity using VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif_data = pd.DataFrame()
vif_data["feature"] = x.columns
vif_data["VIF"] = [variance_inflation_factor(x.values, i)
                          for i in range(len(x.columns))]
print(vif_data)
# Out:
#                feature           VIF
# 0      passenger_count      2.940446
# 1                 Year     15.488873
# 2                Month      4.322775
# 3                  Day      4.271844
# 4                 Hour      5.308206
# 5             Day_Name      1.183140
# 6             distance      2.421035
# 7   final_pickup_point  14076.695508
# 8  final_dropoff_point  14077.123850

# %% [markdown]
# # since final_pickup_point andfinal_dropoff_point are highly correlated will drop one among them

# %%
df.drop(columns=['final_dropoff_point',],inplace=True)

# %%
x=df.drop(columns=['fare_amount'])
x.head(2)
# Out:
#    passenger_count  Year  Month  Day  Hour  Day_Name  distance  \
# 0              1.0  2015      5    7    19         0      1.68
# 1              1.0  2009      7   17    20         1      2.46
#
#    final_pickup_point
# 0                1.67
# 1                1.66

# %%
vif_data = pd.DataFrame()
vif_data["feature"] = x.columns
vif_data["VIF"] = [variance_inflation_factor(x.values, i)
                          for i in range(len(x.columns))]
print(vif_data)
# Out:
#               feature        VIF
# 0     passenger_count   2.940411
# 1                Year  15.488868
# 2               Month   4.322513
# 3                 Day   4.270478
# 4                Hour   5.306854
# 5            Day_Name   1.183089
# 6            distance   2.420747
# 7  final_pickup_point   1.024159

# %% [markdown]
# # now VIF looks some what fine so we move ahead for modelling

# %%
df.head(2)
# Out:
#    fare_amount  passenger_count  Year  Month  Day  Hour  Day_Name  distance  \
# 0          7.5              1.0  2015      5    7    19         0      1.68
# 1          7.7              1.0  2009      7   17    20         1      2.46
#
#    final_pickup_point
# 0                1.67
# 1                1.66

# %%
y=df['fare_amount']
y.head(2)
# Out:
# 0    7.5
# 1    7.7
# Name: fare_amount, dtype: float64

# %%
df.shape
# Out:
# (182605, 9)

# %% [markdown]
# # Test Train Split

# %%
from sklearn.model_selection import  train_test_split
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y, test_size=0.2,random_state=42)

# %%
scaled = StandardScaler()

# %% [markdown]
# # Model With  Linear Regression

# %%
lr=LinearRegression(normalize=True)

# %% [markdown]
# # creating pipeline

# %%
pipe = make_pipeline(scaled,lr)

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression(normalize=True))])

# %%
y_predicted = pipe.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error as MSE

accuracy0 = pipe.score(x_test,y_test)
MSE_score = MSE(y_test,y_predicted)


print("R2 value :",r2_score (y_test,y_predicted))
print("Adjusted R2:",1 - (1-pipe.score(x, y))*(len(y)-1)/(len(y)-x.shape[1]-1))

print("Training Accuracy0:",pipe.score(x_train,y_train))
print("Testing Accuracy0:",accuracy0)
print("Mean Squared Error",MSE_score.mean())

import math
print("Root Mean Squared Error",math.sqrt(MSE_score.mean())) 

from sklearn.metrics import mean_absolute_error
print("Mean Absolute Error",mean_absolute_error(y_test, y_predicted))
# Out:
# R2 value : 0.7786037395309162
# Adjusted R2: 0.7797429817307795
# Training Accuracy0: 0.7800378054177249
# Testing Accuracy0: 0.7786037395309162
# Mean Squared Error 7.885318275020111
# Root Mean Squared Error 2.80808088826161
# Mean Absolute Error 1.8683141972683166

# %% [markdown]
# # Model With Ridge Regression

# %%
from sklearn.linear_model import Ridge

ridgereg=Ridge(alpha=0.001,normalize=True)

pipe2 = make_pipeline(scaled,ridgereg)
pipe2.fit(x_train,y_train)
y_predicted = pipe2.predict(x_test)
print("R2 value :",r2_score (y_test,y_predicted))
print("Adjusted R2:",1 - (1-pipe2.score(x, y))*(len(y)-1)/(len(y)-x.shape[1]-1))

accuracy1 = pipe2.score(x_test,y_test)
MSE_score1 = MSE(y_test,y_predicted)

print("Training Accuracy0:",pipe2.score(x_train,y_train))
print("Testing Accuracy0:",accuracy1)
print("Mean Squared Error",MSE_score1.mean())
import math
print("Root Mean Squared Error",math.sqrt(MSE_score1.mean())) 

from sklearn.metrics import mean_absolute_error
print("Mean Absolute Error",mean_absolute_error(y_test, y_predicted))
# Out:
# R2 value : 0.7786046048744016
# Adjusted R2: 0.7797424551968601
# Training Accuracy0: 0.7800369315626208
# Testing Accuracy0: 0.7786046048744016
# Mean Squared Error 7.885287454676602
# Root Mean Squared Error 2.808075400461427
# Mean Absolute Error 1.868395809260568

# %% [markdown]
# # Model With Lasso Regression

# %%
from sklearn.linear_model import Lasso

regressor=Lasso(alpha=0.001,normalize=True)

pipe2 = make_pipeline(scaled,regressor)
pipe2.fit(x_train,y_train)
y_predicted = pipe2.predict(x_test)
print("R2 value :",r2_score (y_test,y_predicted))
print("Adjusted R2:",1 - (1-pipe2.score(x, y))*(len(y)-1)/(len(y)-x.shape[1]-1))

accuracy1 = pipe2.score(x_test,y_test)
MSE_score1 = MSE(y_test,y_predicted)

print("Training Accuracy0:",pipe2.score(x_train,y_train))
print("Testing Accuracy0:",accuracy1)
print("Mean Squared Error",MSE_score1.mean())
import math
print("Root Mean Squared Error",math.sqrt(MSE_score1.mean())) 

from sklearn.metrics import mean_absolute_error
print("Mean Absolute Error",mean_absolute_error(y_test, y_predicted))
# Out:
# R2 value : 0.7628747289276614
# Adjusted R2: 0.7643789879938732
# Training Accuracy0: 0.7647656365490818
# Testing Accuracy0: 0.7628747289276614
# Mean Squared Error 8.445527623159263
# Root Mean Squared Error 2.906118996730737
# Mean Absolute Error 1.9437028602132211

# %% [markdown]
# # Model with Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

regressor=DecisionTreeRegressor(max_depth=5,min_samples_leaf=20,random_state=0)

pipe= make_pipeline(scaled,regressor)
pipe.fit(x_train,y_train)
y_predicted = pipe.predict(x_test)
print("R2 value :",r2_score (y_test,y_predicted))
print("Adjusted R2:",1 - (1-pipe.score(x, y))*(len(y)-1)/(len(y)-x.shape[1]-1))

accuracy1 = pipe.score(x_test,y_test)
MSE_score1 = MSE(y_test,y_predicted)

print("Training Accuracy0:",pipe.score(x_train,y_train))
print("Testing Accuracy0:",accuracy1)
print("Mean Squared Error",MSE_score1.mean())

print("Root Mean Squared Error",math.sqrt(MSE_score1.mean())) 


print("Mean Absolute Error",mean_absolute_error(y_test, y_predicted))
# Out:
# R2 value : 0.7985447822694929
# Adjusted R2: 0.7993167251099583
# Training Accuracy0: 0.7995189532007405
# Testing Accuracy0: 0.7985447822694929
# Mean Squared Error 7.175091876451772
# Root Mean Squared Error 2.6786361971069854
# Mean Absolute Error 1.809414859295147

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

trf2 =RandomForestRegressor(max_depth=5,min_samples_leaf=20,bootstrap= True,random_state=0,n_estimators=200)

pipe= make_pipeline(scaled,trf2)
pipe.fit(x_train,y_train)
y_predicted = pipe.predict(x_test)
print("R2 value :",r2_score (y_test,y_predicted))
print("Adjusted R2:",1 - (1-pipe.score(x, y))*(len(y)-1)/(len(y)-x.shape[1]-1))

accuracy1 = pipe.score(x_test,y_test)
MSE_score1 = MSE(y_test,y_predicted)

print("Training Accuracy0:",pipe.score(x_train,y_train))
print("Testing Accuracy0:",accuracy1)
print("Mean Squared Error",MSE_score1.mean())

print("Root Mean Squared Error",math.sqrt(MSE_score1.mean())) 


print("Mean Absolute Error",mean_absolute_error(y_test, y_predicted))
# Out:
# R2 value : 0.8015429593174666
# Adjusted R2: 0.8025184253554285
# Training Accuracy0: 0.8027712901822621
# Testing Accuracy0: 0.8015429593174666
# Mean Squared Error 7.06830786746245
# Root Mean Squared Error 2.6586289450508978
# Mean Absolute Error 1.7936527769128487

# %%
from pprint import pprint
# Look at parameters used by our current forest
print('Parameters currently in use:\n')
pprint(trf2.get_params())
# Out:
# Parameters currently in use:
#
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': 5,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 20,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 200,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 0,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# # comparison

# %%
for i,j in zip(y_test,y_predicted):
    print(i,"<->",round(j,2))
# Out:
# 5.3 <-> 5.21
# 6.5 <-> 9.72
# 4.5 <-> 5.21
# 5.5 <-> 5.21
# 8.5 <-> 8.66
# 5.3 <-> 6.28
# 6.5 <-> 6.28
# 10.5 <-> 11.89
# 4.1 <-> 5.21
# 26.0 <-> 24.36
# 8.5 <-> 9.06
# 6.1 <-> 6.9
# 6.5 <-> 6.9
# 14.1 <-> 16.12
# 12.5 <-> 10.97
# 6.5 <-> 6.5
# 6.5 <-> 6.9
# 6.0 <-> 6.28
# 4.0 <-> 5.21
# 5.3 <-> 6.89
# 8.5 <-> 9.13
# 6.9 <-> 5.21
# 5.7 <-> 6.85
# 18.9 <-> 17.89
# 17.3 <-> 27.37
# 5.3 <-> 6.28
# 18.1 <-> 26.12
# 6.5 <-> 6.91
# 6.1 <-> 6.28
# 9.7 <-> 10.87
# 18.1 <-> 17.81
# 8.9 <-> 8.66
# 18.5 <-> 15.01
# 8.0 <-> 5.73
# 6.5 <-> 6.28
# 2.5 <-> 6.23
# 7.3 <-> 6.42
# 7.0 <-> 9.15
# 11.5 <-> 10.87
# 7.0 <-> 7.96
# 19.7 <-> 6.93
# 6.5 <-> 6.28
# 10.5 <-> 12.23
# 4.0 <-> 5.21
# 14.0 <-> 16.2
# 15.3 <-> 15.7
# 13.5 <-> 10.51
# 4.5 <-> 5.72
# 4.9 <-> 9.83
# 20.1 <-> 17.75
# 5.5 <-> 6.28
# 6.1 <-> 6.43
# 12.5 <-> 10.33
# 16.0 <-> 9.15
# 10.1 <-> 13.51
# 4.5 <-> 5.21
# 5.3 <-> 6.9
# 10.0 <-> 5.25
# 12.5 <-> 12.13
# 6.0 <-> 5.21
# 4.5 <-> 10.08
# 15.7 <-> 17.6
# 9.7 <-> 8.66
# 4.5 <-> 5.21
# 10.5 <-> 9.9
# 8.0 <-> 6.28
# 4.9 <-> 5.98
# 6.9 <-> 6.9
# 4.1 <-> 5.98
# 5.7 <-> 6.9
# 7.3 <-> 7.44
# 10.9 <-> 8.98
# 7.7 <-> 6.9
# 5.7 <-> 6.19
# 6.5 <-> 6.28
# 14.1 <-> 13.6
# 4.5 <-> 6.29
# 22.0 <-> 18.28
# 4.5 <-> 6.89
# 8.9 <-> 6.9
# 12.0 <-> 10.44
# 5.7 <-> 6.28
# 12.0 <-> 9.6
# 32.67 <-> 26.12
# 8.5 <-> 8.66
# 11.0 <-> 8.01
# 7.7 <-> 7.71
# 5.3 <-> 6.9
# 7.5 <-> 6.28
# 10.9 <-> 7.71
# 7.7 <-> 12.13
# 8.5 <-> 10.33
# 7.0 <-> 8.66
# 5.7 <-> 6.9
# 6.1 <-> 6.28
# 18.9 <-> 25.94
# 7.5 <-> 6.89
# 10.1 <-> 8.67
# 15.3 <-> 9.9
# 6.5 <-> 6.9
# 3.7 <-> 6.28
# 8.9 <-> 9.78
# 5.7 <-> 6.29
# 19.5 <-> 13.39
# 9.5 <-> 9.15
# 5.7 <-> 5.21
# 18.1 <-> 6.23
# 9.5 <-> 8.01
# 7.3 <-> 7.71
# 6.9 <-> 6.19
# 5.5 <-> 6.9
# 4.5 <-> 5.21
# 4.0 <-> 5.21
# 4.9 <-> 6.88
# 8.1 <-> 7.71
# 7.5 <-> 9.72
# 5.3 <-> 5.21
# 4.9 <-> 7.44
# 6.0 <-> 7.87
# 38.5 <-> 26.12
# 27.5 <-> 30.44
# 5.0 <-> 5.6
# 20.0 <-> 14.58
# 34.54 <-> 31.88
# 24.5 <-> 11.85
# 7.3 <-> 6.28
# 10.1 <-> 12.19
# 17.5 <-> 18.33
# 17.0 <-> 17.05
# 36.83 <-> 31.21
# 5.0 <-> 5.21
# 11.5 <-> 11.96
# 6.5 <-> 8.1
# 6.1 <-> 6.28
# 8.1 <-> 7.16
# 7.0 <-> 5.25
# 13.3 <-> 9.57
# 5.7 <-> 5.24
# 11.7 <-> 12.13
# 5.7 <-> 6.28
# 14.5 <-> 15.11
# 12.6 <-> 13.35
# 6.1 <-> 6.9
# 9.3 <-> 10.65
# 12.9 <-> 13.58
# 6.5 <-> 7.1
# 4.5 <-> 5.21
# 8.0 <-> 7.71
# 6.1 <-> 6.9
# 28.94 <-> 30.61
# 20.5 <-> 19.69
# 6.5 <-> 6.9
# 10.1 <-> 5.21
# 8.5 <-> 9.14
# 16.5 <-> 16.49
# 4.5 <-> 5.23
# 5.3 <-> 5.24
# 14.5 <-> 16.88
# 8.0 <-> 9.15
# 2.5 <-> 5.28
# 23.07 <-> 9.57
# 5.5 <-> 6.28
# 5.3 <-> 6.26
# 12.9 <-> 14.42
# 10.5 <-> 8.66
# 7.0 <-> 5.73
# 5.7 <-> 6.84
# 17.7 <-> 16.64
# 8.1 <-> 8.6
# 5.7 <-> 7.71
# 17.0 <-> 15.12
# 7.3 <-> 6.28
# 8.9 <-> 7.71
# 6.5 <-> 6.28
# 5.5 <-> 5.21
# 7.3 <-> 7.71
# 4.5 <-> 6.28
# 10.9 <-> 10.87
# 4.1 <-> 5.21
# 12.0 <-> 11.87
# 22.5 <-> 29.58
# 8.0 <-> 6.29
# 6.5 <-> 7.57
# 7.0 <-> 7.35
# 5.0 <-> 5.21
# 12.9 <-> 17.89
# 8.5 <-> 11.84
# 18.0 <-> 12.17
# 22.0 <-> 19.35
# 9.7 <-> 10.88
# 8.9 <-> 8.66
# 8.5 <-> 5.3
# 9.7 <-> 12.13
# 25.3 <-> 26.12
# 9.5 <-> 9.78
# 10.5 <-> 12.94
# 7.7 <-> 7.71
# 12.9 <-> 13.58
# 16.5 <-> 21.58
# 8.9 <-> 8.03
# 13.3 <-> 14.54
# 5.7 <-> 6.28
# 16.1 <-> 17.6
# 17.5 <-> 18.32
# 8.5 <-> 9.8
# 13.3 <-> 14.65
# 20.0 <-> 13.4
# 4.1 <-> 5.21
# 4.5 <-> 5.21
# 9.7 <-> 10.34
# 8.1 <-> 6.28
# 4.9 <-> 5.23
# 12.5 <-> 13.74
# 7.0 <-> 8.34
# 5.7 <-> 6.08
# 5.7 <-> 5.69
# 10.9 <-> 8.67
# 9.5 <-> 6.23
# 17.0 <-> 18.37
# 10.9 <-> 9.89
# 21.0 <-> 23.5
# 11.5 <-> 11.85
# 17.5 <-> 11.95
# 7.7 <-> 7.71
# 7.5 <-> 9.14
# 5.7 <-> 6.9
# 11.3 <-> 10.01
# 35.0 <-> 30.32
# 14.1 <-> 18.59
# 14.5 <-> 15.02
# 4.5 <-> 5.21
# 28.1 <-> 17.75
# 4.5 <-> 6.19
# 5.5 <-> 5.66
# 8.5 <-> 5.26
# 19.5 <-> 19.39
# 14.1 <-> 9.8
# 6.1 <-> 6.28
# 21.0 <-> 22.64
# 11.5 <-> 10.51
# 4.9 <-> 5.21
# 4.1 <-> 5.21
# 3.3 <-> 5.21
# 15.7 <-> 16.89
# 7.3 <-> 6.9
# 6.1 <-> 8.66
# 3.0 <-> 5.22
# 9.7 <-> 7.71
# 4.9 <-> 5.23
# 13.3 <-> 12.23
# 4.5 <-> 6.28
# 4.9 <-> 6.28
# 7.0 <-> 9.15
# 6.9 <-> 6.9
# 29.0 <-> 33.04
# 38.33 <-> 30.24
# 6.0 <-> 8.18
# 10.0 <-> 5.3
# 5.7 <-> 6.9
# 14.1 <-> 9.57
# 7.5 <-> 6.9
# 21.3 <-> 26.12
# 5.3 <-> 8.03
# 10.1 <-> 9.22
# 4.0 <-> 6.26
# 14.5 <-> 11.85
# 6.0 <-> 5.21
# 9.3 <-> 12.13
# 5.7 <-> 5.73
# 20.0 <-> 9.16
# 5.7 <-> 5.6
# 6.5 <-> 6.85
# 3.5 <-> 5.24
# 6.5 <-> 6.42
# 4.9 <-> 5.21
# 8.5 <-> 10.88
# 35.0 <-> 26.12
# 12.0 <-> 9.8
# 14.9 <-> 9.57
# 7.5 <-> 7.71
# 3.7 <-> 5.21
# 6.5 <-> 5.72
# 3.7 <-> 5.21
# 18.1 <-> 14.71
# 5.7 <-> 5.22
# 10.1 <-> 12.13
# 6.5 <-> 8.37
# 6.0 <-> 5.98
# 11.7 <-> 13.5
# 7.5 <-> 8.12
# 13.0 <-> 8.93
# 25.3 <-> 26.21
# 17.5 <-> 18.28
# 22.5 <-> 13.59
# 4.5 <-> 5.23
# 8.5 <-> 6.28
# 9.0 <-> 9.23
# 8.0 <-> 8.93
# 6.9 <-> 7.72
# 11.7 <-> 15.16
# 10.1 <-> 6.28
# 7.3 <-> 7.73
# 7.0 <-> 11.72
# 5.3 <-> 6.29
# 7.0 <-> 9.02
# 10.1 <-> 6.88
# 8.1 <-> 9.8
# 9.7 <-> 12.58
# 5.5 <-> 5.21
# 8.5 <-> 9.77
# 28.83 <-> 30.44
# 5.3 <-> 6.28
# 8.0 <-> 8.33
# 6.1 <-> 6.28
# 16.1 <-> 17.6
# 23.5 <-> 22.02
# 6.5 <-> 5.95
# 7.7 <-> 8.66
# 7.3 <-> 7.57
# 5.0 <-> 5.21
# 7.5 <-> 10.41
# 4.0 <-> 5.21
# 6.5 <-> 9.15
# 6.1 <-> 6.43
# 9.5 <-> 11.84
# 8.0 <-> 10.41
# 4.1 <-> 5.21
# 7.5 <-> 9.15
# 11.0 <-> 6.19
# 8.0 <-> 5.24
# 7.5 <-> 6.28
# 8.0 <-> 8.08
# 14.5 <-> 15.23
# 5.7 <-> 6.9
# 9.0 <-> 9.15
# 5.5 <-> 5.21
# 5.3 <-> 5.73
# 8.9 <-> 7.76
# 5.7 <-> 5.22
# 7.0 <-> 6.82
# 10.5 <-> 13.58
# 12.0 <-> 11.81
# 21.5 <-> 22.05
# 10.5 <-> 12.13
# 14.5 <-> 10.51
# 8.9 <-> 9.13
# 5.3 <-> 6.28
# 4.9 <-> 6.28
# 8.0 <-> 7.77
# 5.7 <-> 6.91
# 5.7 <-> 9.01
# 4.9 <-> 6.28
# 15.5 <-> 10.53
# 6.5 <-> 6.9
# 4.9 <-> 6.24
# 10.5 <-> 13.31
# 19.5 <-> 17.97
# 9.0 <-> 8.13
# 6.5 <-> 7.87
# 14.5 <-> 13.26
# 4.1 <-> 5.69
# 6.0 <-> 8.93
# 10.0 <-> 8.66
# 8.5 <-> 8.08
# 8.1 <-> 6.9
# 9.0 <-> 10.41
# 3.3 <-> 5.21
# 8.5 <-> 9.17
# 12.0 <-> 7.99
# 13.0 <-> 13.53
# 8.5 <-> 8.66
# 5.0 <-> 5.21
# 10.5 <-> 9.15
# 6.1 <-> 6.19
# 5.7 <-> 7.71
# 4.1 <-> 6.28
# 6.1 <-> 6.28
# 5.7 <-> 6.28
# 14.9 <-> 12.13
# 4.0 <-> 5.21
# 23.3 <-> 26.12
# 16.3 <-> 16.5
# 9.0 <-> 6.19
# 6.1 <-> 6.91
# 7.3 <-> 7.71
# 9.5 <-> 13.26
# 3.7 <-> 5.21
# 5.3 <-> 5.66
# 7.3 <-> 7.72
# 4.9 <-> 5.3
# 5.3 <-> 6.28
# 4.0 <-> 10.44
# 4.9 <-> 6.28
# 5.3 <-> 6.28
# 8.0 <-> 6.24
# 12.5 <-> 12.93
# 10.5 <-> 10.42
# 8.9 <-> 8.59
# 19.5 <-> 17.8
# 6.9 <-> 6.82
# 6.1 <-> 6.82
# 10.5 <-> 9.64
# 11.3 <-> 12.05
# 9.3 <-> 9.9
# 6.1 <-> 5.21
# 6.1 <-> 6.23
# 11.3 <-> 12.13
# 5.7 <-> 6.9
# 6.9 <-> 7.71
# 9.7 <-> 9.57
# 11.3 <-> 8.67
# 12.0 <-> 6.28
# 8.9 <-> 10.88
# 29.5 <-> 17.89
# 16.5 <-> 14.73
# 10.5 <-> 7.77
# 6.9 <-> 9.14
# 9.0 <-> 9.05
# 22.1 <-> 25.44
# 36.54 <-> 30.28
# 8.1 <-> 6.88
# 9.0 <-> 10.42
# 8.0 <-> 5.21
# 10.5 <-> 9.6
# 13.0 <-> 13.32
# 9.0 <-> 9.15
# 5.3 <-> 6.89
# 18.9 <-> 17.6
# 7.7 <-> 7.71
# 15.0 <-> 16.46
# 3.3 <-> 5.21
# 3.3 <-> 5.21
# 11.5 <-> 13.26
# 3.5 <-> 5.21
# 35.83 <-> 32.96
# 7.7 <-> 8.66
# 8.5 <-> 10.65
# 6.9 <-> 6.9
# 12.5 <-> 9.79
# 9.0 <-> 10.13
# 17.0 <-> 16.49
# 11.5 <-> 9.14
# 13.7 <-> 8.66
# 7.7 <-> 8.66
# 5.7 <-> 6.28
# 10.0 <-> 13.74
# 10.5 <-> 9.89
# 15.0 <-> 13.58
# 6.5 <-> 5.21
# 16.0 <-> 18.37
# 6.0 <-> 10.08
# 7.7 <-> 9.16
# 4.5 <-> 6.28
# 6.5 <-> 9.23
# 8.5 <-> 8.93
# 4.9 <-> 5.73
# 4.9 <-> 6.23
# 6.1 <-> 6.9
# 5.5 <-> 5.21
# 4.9 <-> 5.21
# 14.0 <-> 13.3
# 7.7 <-> 7.73
# 23.5 <-> 21.37
# 7.5 <-> 6.28
# 8.6 <-> 6.9
# 10.5 <-> 9.81
# 16.0 <-> 6.23
# 25.0 <-> 5.28
# 12.9 <-> 13.71
# 7.5 <-> 7.77
# 8.1 <-> 7.77
# 14.5 <-> 9.15
# 9.7 <-> 13.56
# 10.1 <-> 10.98
# 8.9 <-> 9.77
# 4.5 <-> 5.21
# 16.5 <-> 5.28
# 10.5 <-> 11.84
# 6.0 <-> 5.26
# 7.0 <-> 6.28
# 12.0 <-> 9.14
# 9.7 <-> 14.62
# 6.1 <-> 5.21
# 6.5 <-> 6.69
# 8.0 <-> 9.15
# 19.8 <-> 26.12
# 9.3 <-> 6.28
# 10.0 <-> 10.35
# 3.3 <-> 5.21
# 8.5 <-> 6.28
# 5.5 <-> 5.66
# 4.1 <-> 5.21
# 8.1 <-> 10.87
# 8.1 <-> 8.66
# 31.83 <-> 30.17
# 8.1 <-> 5.21
# 10.5 <-> 12.13
# 7.0 <-> 9.15
# 20.0 <-> 13.75
# 11.7 <-> 9.8
# 4.9 <-> 6.28
# 18.0 <-> 19.83
# 5.5 <-> 7.87
# 6.1 <-> 6.9
# 5.3 <-> 5.24
# 3.3 <-> 5.21
# 5.3 <-> 5.72
# 11.0 <-> 10.41
# 13.0 <-> 12.0
# 11.5 <-> 11.84
# 10.5 <-> 9.05
# 9.0 <-> 6.28
# 10.1 <-> 9.79
# 9.5 <-> 10.19
# 7.3 <-> 8.66
# 30.83 <-> 30.04
# 7.7 <-> 8.66
# 7.7 <-> 7.71
# 11.3 <-> 5.28
# 12.0 <-> 6.28
# 8.5 <-> 6.19
# 3.7 <-> 6.82
# 6.1 <-> 8.66
# 7.5 <-> 8.37
# 7.0 <-> 6.28
# 4.5 <-> 5.21
# 4.0 <-> 5.21
# 11.3 <-> 8.66
# 6.9 <-> 6.84
# 6.5 <-> 6.28
# 10.5 <-> 14.72
# 5.3 <-> 7.71
# 4.9 <-> 5.21
# 17.7 <-> 14.72
# 6.5 <-> 7.77
# 6.9 <-> 7.71
# 4.5 <-> 5.21
# 3.7 <-> 5.21
# 6.9 <-> 9.8
# 8.5 <-> 8.66
# 15.5 <-> 11.86
# 33.7 <-> 23.32
# 7.3 <-> 5.25
# 9.5 <-> 10.33
# 12.0 <-> 7.07
# 8.5 <-> 11.97
# 7.7 <-> 6.9
# 5.5 <-> 5.95
# 18.0 <-> 16.6
# 12.9 <-> 14.58
# 4.9 <-> 6.28
# 9.5 <-> 6.29
# 7.7 <-> 7.71
# 6.1 <-> 6.28
# 5.7 <-> 5.69
# 8.0 <-> 10.41
# 10.1 <-> 12.13
# 6.1 <-> 7.16
# 10.1 <-> 11.75
# 9.0 <-> 8.18
# 8.6 <-> 9.79
# 6.0 <-> 6.29
# 5.5 <-> 6.28
# 31.2 <-> 28.81
# 5.7 <-> 6.85
# 13.0 <-> 13.26
# 7.3 <-> 9.59
# 19.5 <-> 17.13
# 5.3 <-> 5.21
# 4.0 <-> 5.21
# 5.0 <-> 5.21
# 22.0 <-> 22.65
# 6.5 <-> 9.6
# 10.5 <-> 10.42
# 5.3 <-> 7.71
# 5.3 <-> 6.08
# 5.0 <-> 10.02
# 10.0 <-> 10.44
# 21.5 <-> 26.16
# 10.5 <-> 9.92
# 4.5 <-> 6.67
# 12.5 <-> 5.28
# 14.5 <-> 13.61
# 17.0 <-> 15.02
# 12.9 <-> 13.58
# 9.0 <-> 8.01
# 36.83 <-> 32.96
# 5.3 <-> 6.28
# 15.5 <-> 16.49
# 9.0 <-> 8.01
# 10.9 <-> 9.77
# 18.5 <-> 15.14
# 5.7 <-> 6.9
# 4.5 <-> 5.21
# 28.1 <-> 29.11
# 16.1 <-> 16.93
# 8.9 <-> 8.66
# 18.0 <-> 11.8
# 8.5 <-> 10.42
# 13.3 <-> 14.64
# 3.7 <-> 5.21
# 6.9 <-> 5.98
# 14.1 <-> 16.89
# 9.0 <-> 8.01
# 6.5 <-> 6.28
# 14.9 <-> 14.54
# 14.5 <-> 13.57
# 15.3 <-> 16.64
# 5.0 <-> 5.72
# 7.7 <-> 7.16
# 6.9 <-> 5.22
# 4.1 <-> 5.21
# 21.5 <-> 22.17
# 6.5 <-> 6.28
# 6.5 <-> 10.19
# 7.3 <-> 6.28
# 8.5 <-> 8.66
# 19.0 <-> 15.22
# 10.0 <-> 9.05
# 9.7 <-> 6.45
# 26.1 <-> 26.12
# 12.1 <-> 12.13
# 11.0 <-> 6.28
# 7.3 <-> 6.28
# 19.5 <-> 15.14
# 22.0 <-> 25.58
# 10.5 <-> 10.66
# 7.0 <-> 5.21
# 11.3 <-> 5.28
# 11.5 <-> 9.73
# 11.0 <-> 14.93
# 20.0 <-> 17.05
# 6.5 <-> 6.28
# 6.5 <-> 6.28
# 6.9 <-> 7.71
# 12.5 <-> 12.44
# 7.5 <-> 9.14
# 8.5 <-> 9.58
# 6.0 <-> 6.65
# 14.2 <-> 14.58
# 6.5 <-> 6.28
# 9.5 <-> 8.02
# 4.5 <-> 6.28
# 13.0 <-> 11.85
# 5.3 <-> 6.42
# 6.5 <-> 5.21
# 7.3 <-> 6.9
# 6.1 <-> 9.13
# 6.5 <-> 5.3
# 8.5 <-> 9.13
# 25.0 <-> 25.58
# 4.5 <-> 5.21
# 14.5 <-> 5.21
# 6.0 <-> 5.6
# 7.5 <-> 10.41
# 18.5 <-> 18.24
# 5.3 <-> 6.85
# 6.5 <-> 8.34
# 8.5 <-> 8.1
# 6.0 <-> 10.41
# 14.1 <-> 12.13
# 11.3 <-> 12.13
# 20.5 <-> 17.02
# 8.9 <-> 10.66
# 4.9 <-> 6.9
# 3.7 <-> 5.21
# 5.7 <-> 6.28
# 14.9 <-> 13.64
# 5.5 <-> 5.6
# 6.9 <-> 7.71
# 4.5 <-> 5.21
# 12.9 <-> 14.72
# 8.0 <-> 8.01
# 7.5 <-> 8.77
# 20.9 <-> 13.58
# 10.5 <-> 12.23
# 12.5 <-> 12.19
# 15.5 <-> 8.08
# 3.0 <-> 5.28
# 6.9 <-> 9.79
# 4.9 <-> 5.21
# 5.3 <-> 6.9
# 33.0 <-> 30.44
# 3.7 <-> 5.21
# 8.5 <-> 7.71
# 8.1 <-> 6.9
# 13.5 <-> 13.26
# 3.7 <-> 5.21
# 10.9 <-> 10.88
# 6.5 <-> 6.84
# 2.5 <-> 5.28
# 10.9 <-> 10.87
# 4.5 <-> 5.24
# 8.9 <-> 7.71
# 21.0 <-> 17.05
# 2.5 <-> 6.23
# 10.5 <-> 12.56
# 11.7 <-> 9.13
# 6.9 <-> 6.9
# 10.5 <-> 12.19
# 8.5 <-> 6.28
# 6.5 <-> 9.14
# 4.9 <-> 5.69
# 5.3 <-> 9.57
# 5.3 <-> 6.43
# 16.0 <-> 16.96
# 15.3 <-> 10.94
# 6.5 <-> 6.28
# 10.5 <-> 11.86
# 13.5 <-> 11.84
# 4.9 <-> 6.26
# 39.33 <-> 25.95
# 16.9 <-> 13.58
# 5.3 <-> 6.08
# 8.5 <-> 10.42
# 6.1 <-> 6.9
# 8.5 <-> 8.1
# 3.7 <-> 5.24
# 7.3 <-> 6.9
# 10.5 <-> 6.28
# 14.1 <-> 13.58
# 13.0 <-> 17.42
# 6.1 <-> 6.08
# 11.0 <-> 12.0
# 8.1 <-> 7.71
# 7.0 <-> 6.23
# 8.5 <-> 10.43
# 4.5 <-> 5.21
# 11.5 <-> 12.56
# 5.0 <-> 5.21
# 10.5 <-> 13.15
# 14.0 <-> 13.26
# 9.3 <-> 6.9
# 27.0 <-> 29.45
# 5.7 <-> 6.91
# 9.5 <-> 10.41
# 15.0 <-> 14.2
# 14.9 <-> 15.23
# 3.3 <-> 5.21
# 4.9 <-> 7.71
# 6.9 <-> 8.66
# 8.0 <-> 5.21
# 8.5 <-> 10.94
# 9.7 <-> 7.71
# 8.9 <-> 8.66
# 7.3 <-> 9.14
# 25.0 <-> 30.17
# 8.5 <-> 6.28
# 9.5 <-> 5.72
# 8.0 <-> 10.41
# 19.3 <-> 21.7
# 22.0 <-> 22.51
# 10.5 <-> 7.87
# 3.5 <-> 5.21
# 14.0 <-> 6.19
# 5.3 <-> 6.9
# 5.0 <-> 5.21
# 8.9 <-> 9.92
# 7.0 <-> 6.28
# 4.1 <-> 5.21
# 14.5 <-> 6.65
# 17.0 <-> 17.78
# 6.5 <-> 5.21
# 8.1 <-> 8.66
# 4.5 <-> 6.28
# 27.3 <-> 16.99
# 5.5 <-> 6.9
# 8.9 <-> 8.59
# 9.7 <-> 8.66
# 6.0 <-> 6.28
# 9.5 <-> 11.8
# 10.0 <-> 10.42
# 4.9 <-> 5.21
# 14.0 <-> 15.12
# 4.1 <-> 5.24
# 12.5 <-> 13.56
# 6.0 <-> 5.21
# 8.1 <-> 6.88
# 3.7 <-> 5.21
# 16.1 <-> 17.6
# 11.0 <-> 8.01
# 6.9 <-> 8.67
# 6.9 <-> 6.28
# 6.9 <-> 6.9
# 10.9 <-> 10.87
# 3.3 <-> 5.21
# 3.7 <-> 5.21
# 3.7 <-> 5.21
# 4.5 <-> 5.21
# 6.5 <-> 7.99
# 4.9 <-> 6.29
# 3.7 <-> 5.21
# 25.7 <-> 18.13
# 3.0 <-> 5.21
# 5.3 <-> 5.21
# 10.0 <-> 13.26
# 9.3 <-> 9.58
# 20.0 <-> 13.51
# 9.3 <-> 9.79
# 5.7 <-> 6.19
# 6.9 <-> 6.84
# 4.1 <-> 5.21
# 5.3 <-> 5.95
# 4.0 <-> 5.21
# 7.3 <-> 6.93
# 8.0 <-> 7.87
# 7.3 <-> 7.85
# 22.5 <-> 14.97
# 7.0 <-> 5.22
# 9.7 <-> 8.98
# 11.3 <-> 8.67
# 4.0 <-> 5.21
# 4.5 <-> 9.57
# 11.0 <-> 11.89
# 4.1 <-> 5.23
# 7.3 <-> 6.9
# 7.5 <-> 7.71
# 5.0 <-> 6.08
# 10.5 <-> 7.1
# 7.7 <-> 5.21
# 4.5 <-> 5.21
# 8.9 <-> 10.88
# 5.3 <-> 10.04
# 19.5 <-> 14.56
# 8.1 <-> 7.68
# 8.9 <-> 9.06
# 6.1 <-> 5.21
# 6.9 <-> 6.28
# 15.0 <-> 11.46
# 10.5 <-> 10.35
# 7.5 <-> 9.18
# 4.0 <-> 5.21
# 11.0 <-> 11.83
# 4.5 <-> 5.95
# 8.0 <-> 10.41
# 7.5 <-> 9.35
# 3.7 <-> 5.21
# 11.7 <-> 13.61
# 10.5 <-> 13.39
# 7.0 <-> 7.99
# 11.0 <-> 10.41
# 6.5 <-> 6.28
# 7.0 <-> 8.86
# 7.0 <-> 6.29
# 5.3 <-> 5.21
# 11.3 <-> 13.58
# 13.0 <-> 12.93
# 13.0 <-> 10.34
# 7.5 <-> 6.28
# 4.9 <-> 6.28
# 10.5 <-> 12.13
# 8.5 <-> 6.28
# 6.5 <-> 6.89
# 22.5 <-> 18.26
# 8.0 <-> 8.93
# 6.0 <-> 10.19
# 22.0 <-> 16.99
# 10.0 <-> 9.35
# 4.9 <-> 6.28
# 36.33 <-> 30.44
# 8.1 <-> 6.9
# 6.5 <-> 6.89
# 18.9 <-> 18.13
# 4.5 <-> 5.21
# 8.0 <-> 6.28
# 5.7 <-> 6.28
# 7.5 <-> 8.08
# 6.1 <-> 7.71
# 7.5 <-> 7.71
# 8.1 <-> 10.87
# 7.7 <-> 9.21
# 12.5 <-> 13.58
# 4.0 <-> 5.21
# 9.7 <-> 13.39
# 14.1 <-> 12.19
# 7.0 <-> 8.37
# 4.5 <-> 5.21
# 10.0 <-> 8.01
# 5.0 <-> 5.21
# 9.0 <-> 7.71
# 13.5 <-> 11.85
# 9.5 <-> 5.22
# 8.0 <-> 6.28
# 3.3 <-> 5.21
# 32.83 <-> 25.58
# 8.9 <-> 6.28
# 21.7 <-> 13.41
# 15.0 <-> 13.26
# 4.0 <-> 5.21
# 3.7 <-> 5.21
# 4.5 <-> 5.69
# 13.5 <-> 10.19
# 11.5 <-> 11.72
# 9.5 <-> 8.01
# 15.1 <-> 12.19
# 4.9 <-> 8.53
# 5.7 <-> 6.28
# 18.0 <-> 18.38
# 8.1 <-> 10.97
# 11.3 <-> 10.87
# 6.0 <-> 6.28
# 11.7 <-> 6.5
# 5.7 <-> 5.21
# 10.5 <-> 11.75
# 4.5 <-> 6.28
# 5.3 <-> 6.28
# 18.5 <-> 10.52
# 8.9 <-> 8.67
# 7.3 <-> 7.76
# 16.5 <-> 17.97
# 17.5 <-> 17.23
# 8.9 <-> 8.59
# 4.1 <-> 5.21
# 8.5 <-> 11.84
# 4.1 <-> 5.22
# 10.0 <-> 6.28
# 5.0 <-> 5.26
# 14.5 <-> 13.26
# 7.0 <-> 5.28
# 29.5 <-> 30.46
# 6.0 <-> 6.82
# 5.7 <-> 7.16
# 8.5 <-> 12.13
# 4.1 <-> 5.21
# 10.9 <-> 10.87
# 9.5 <-> 9.15
# 12.5 <-> 10.88
# 5.7 <-> 6.93
# 8.5 <-> 6.28
# 2.5 <-> 5.25
# 6.0 <-> 10.21
# 4.9 <-> 6.28
# 4.5 <-> 6.9
# 7.3 <-> 9.57
# 6.1 <-> 6.28
# 7.7 <-> 7.44
# 6.1 <-> 5.69
# 6.5 <-> 6.28
# 5.3 <-> 9.13
# 7.3 <-> 6.9
# 4.9 <-> 5.95
# 3.7 <-> 5.21
# 3.7 <-> 5.21
# 14.0 <-> 10.91
# 22.1 <-> 25.94
# 7.0 <-> 6.28
# 14.5 <-> 14.58
# 4.5 <-> 5.21
# 4.5 <-> 5.24
# 17.7 <-> 13.6
# 7.7 <-> 9.13
# 16.5 <-> 19.72
# 7.0 <-> 9.15
# 8.9 <-> 8.67
# 10.0 <-> 10.44
# 5.5 <-> 6.28
# 8.0 <-> 5.21
# 10.1 <-> 9.8
# 6.9 <-> 8.12
# 26.5 <-> 26.12
# 8.1 <-> 9.13
# 12.5 <-> 10.88
# 12.5 <-> 13.51
# 3.7 <-> 5.21
# 9.3 <-> 8.13
# 7.5 <-> 8.08
# 12.5 <-> 7.77
# 12.0 <-> 11.85
# 3.7 <-> 5.21
# 13.3 <-> 13.57
# 4.5 <-> 6.28
# 10.5 <-> 10.88
# 9.5 <-> 10.41
# 5.5 <-> 9.15
# 6.0 <-> 10.19
# 6.5 <-> 6.9
# 10.1 <-> 5.21
# 8.5 <-> 6.9
# 4.1 <-> 5.21
# 13.0 <-> 12.56
# 9.3 <-> 6.9
# 8.0 <-> 8.18
# 8.1 <-> 9.66
# 8.0 <-> 7.77
# 9.5 <-> 9.17
# 4.5 <-> 6.28
# 11.0 <-> 10.42
# 4.5 <-> 5.21
# 7.7 <-> 8.6
# 14.9 <-> 13.58
# 16.1 <-> 16.93
# 4.9 <-> 6.26
# 6.9 <-> 7.71
# 6.3 <-> 5.66
# 14.5 <-> 11.84
# 6.5 <-> 8.01
# 4.9 <-> 5.21
# 9.3 <-> 9.8
# 8.0 <-> 6.26
# 14.5 <-> 22.39
# 16.1 <-> 14.73
# 5.7 <-> 6.28
# 12.0 <-> 16.99
# 14.9 <-> 17.89
# 4.1 <-> 5.21
# 5.5 <-> 6.28
# 21.7 <-> 16.46
# 6.5 <-> 6.28
# 7.3 <-> 9.83
# 4.9 <-> 5.6
# 12.9 <-> 8.67
# 7.3 <-> 9.13
# 7.5 <-> 9.14
# 8.9 <-> 10.87
# 4.1 <-> 5.73
# 5.7 <-> 5.21
# 6.9 <-> 6.28
# 6.5 <-> 6.82
# 7.3 <-> 9.79
# 17.5 <-> 18.28
# 9.5 <-> 8.58
# 6.1 <-> 6.9
# 13.7 <-> 10.89
# 7.7 <-> 7.71
# 14.1 <-> 12.13
# 4.5 <-> 5.21
# 4.9 <-> 6.28
# 9.5 <-> 9.23
# 8.9 <-> 9.06
# 10.5 <-> 10.51
# 4.1 <-> 5.21
# 15.3 <-> 13.58
# 13.5 <-> 12.56
# 4.1 <-> 5.25
# 15.0 <-> 17.32
# 7.5 <-> 6.28
# 9.7 <-> 9.92
# 14.5 <-> 11.86
# 37.04 <-> 25.58
# 9.5 <-> 11.84
# 10.5 <-> 7.71
# 14.9 <-> 14.73
# 16.1 <-> 9.81
# 8.5 <-> 9.66
# 4.9 <-> 6.28
# 9.0 <-> 7.71
# 9.3 <-> 8.66
# 5.3 <-> 8.12
# 7.5 <-> 6.43
# 6.5 <-> 6.28
# 9.0 <-> 6.28
# 5.0 <-> 6.69
# 6.0 <-> 6.26
# 5.3 <-> 5.23
# 5.7 <-> 5.21
# 13.0 <-> 20.06
# 8.1 <-> 7.71
# 14.5 <-> 17.79
# 6.1 <-> 6.89
# 6.9 <-> 6.28
# 9.0 <-> 9.23
# 21.3 <-> 26.12
# 11.7 <-> 10.94
# 4.9 <-> 5.72
# 9.0 <-> 10.41
# 36.1 <-> 29.45
# 11.7 <-> 11.0
# 30.0 <-> 31.04
# 6.5 <-> 6.9
# 6.9 <-> 10.01
# 10.5 <-> 9.23
# 14.1 <-> 16.13
# 4.9 <-> 6.28
# 9.0 <-> 6.28
# 9.5 <-> 10.44
# 8.0 <-> 10.41
# 5.3 <-> 5.73
# 7.5 <-> 6.5
# 11.0 <-> 13.65
# 8.5 <-> 10.87
# 7.7 <-> 8.66
# 6.0 <-> 7.87
# 9.0 <-> 8.54
# 12.5 <-> 10.36
# 4.1 <-> 6.28
# 6.1 <-> 8.66
# 6.5 <-> 5.95
# 21.3 <-> 26.12
# 8.0 <-> 5.69
# 4.1 <-> 5.21
# 8.5 <-> 6.24
# 13.7 <-> 7.68
# 5.7 <-> 5.24
# 13.5 <-> 16.2
# 11.7 <-> 9.57
# 8.0 <-> 10.42
# 6.9 <-> 8.66
# 6.0 <-> 5.21
# 7.0 <-> 6.08
# 4.5 <-> 6.26
# 4.5 <-> 5.21
# 4.9 <-> 5.72
# 8.0 <-> 9.15
# 10.5 <-> 8.77
# 4.5 <-> 6.28
# 8.0 <-> 6.28
# 3.7 <-> 5.21
# 5.7 <-> 7.71
# 34.5 <-> 25.89
# 6.1 <-> 6.28
# 15.3 <-> 13.58
# 8.9 <-> 9.9
# 9.3 <-> 7.44
# 13.3 <-> 16.8
# 16.0 <-> 15.02
# 10.0 <-> 10.87
# 4.5 <-> 5.21
# 5.7 <-> 8.6
# 14.0 <-> 11.86
# 4.5 <-> 6.28
# 12.5 <-> 11.96
# 4.5 <-> 5.21
# 6.0 <-> 7.99
# 5.7 <-> 6.9
# 9.0 <-> 10.65
# 5.3 <-> 6.43
# 11.3 <-> 10.87
# 7.5 <-> 9.15
# 11.3 <-> 12.08
# 7.3 <-> 9.06
# 10.5 <-> 9.8
# 14.9 <-> 13.58
# 3.7 <-> 5.21
# 9.7 <-> 9.8
# 18.5 <-> 19.83
# 20.5 <-> 13.58
# 8.5 <-> 6.28
# 6.0 <-> 7.99
# 6.5 <-> 6.28
# 15.7 <-> 20.55
# 22.9 <-> 24.02
# 7.5 <-> 13.26
# 10.0 <-> 5.6
# 8.9 <-> 6.23
# 10.0 <-> 10.42
# 5.5 <-> 6.29
# 12.5 <-> 8.1
# 26.5 <-> 30.44
# 34.0 <-> 30.61
# 23.0 <-> 30.3
# 15.0 <-> 17.05
# 9.5 <-> 5.21
# 11.3 <-> 6.9
# 10.5 <-> 11.81
# 32.5 <-> 30.61
# 2.5 <-> 6.23
# 13.5 <-> 13.29
# 9.0 <-> 5.95
# 15.3 <-> 13.65
# 22.5 <-> 27.91
# 8.1 <-> 7.71
# 4.5 <-> 6.45
# 5.7 <-> 6.28
# 8.9 <-> 9.78
# 6.0 <-> 6.28
# 7.5 <-> 5.69
# 5.7 <-> 6.9
# 6.5 <-> 6.65
# 6.1 <-> 7.71
# 9.5 <-> 11.96
# 14.5 <-> 13.26
# 14.9 <-> 9.06
# 10.0 <-> 9.83
# 4.9 <-> 5.25
# 8.5 <-> 7.71
# 6.5 <-> 7.71
# 3.0 <-> 5.22
# 28.9 <-> 28.98
# 4.9 <-> 9.57
# 8.1 <-> 8.66
# 12.5 <-> 15.16
# 6.1 <-> 6.28
# 4.9 <-> 5.21
# 30.5 <-> 31.33
# 11.0 <-> 6.85
# 5.0 <-> 5.69
# 9.0 <-> 8.08
# 11.0 <-> 9.15
# 10.5 <-> 9.8
# 3.3 <-> 5.21
# 6.5 <-> 6.28
# 5.7 <-> 6.28
# 6.0 <-> 10.08
# 5.0 <-> 5.21
# 5.5 <-> 5.6
# 10.1 <-> 10.87
# 23.0 <-> 17.18
# 5.5 <-> 5.28
# 10.0 <-> 8.93
# 10.1 <-> 10.36
# 13.5 <-> 13.32
# 22.0 <-> 26.16
# 6.5 <-> 6.9
# 13.5 <-> 16.96
# 10.5 <-> 6.28
# 9.7 <-> 8.67
# 21.5 <-> 17.81
# 8.5 <-> 7.71
# 7.7 <-> 9.22
# 6.9 <-> 8.66
# 4.5 <-> 5.21
# 19.3 <-> 17.62
# 5.3 <-> 6.28
# 3.3 <-> 5.21
# 5.7 <-> 7.71
# 10.5 <-> 10.86
# 9.3 <-> 8.58
# 12.5 <-> 13.26
# 11.3 <-> 10.65
# 5.0 <-> 6.23
# 4.9 <-> 6.28
# 4.9 <-> 6.28
# 15.7 <-> 13.58
# 4.9 <-> 6.19
# 5.0 <-> 6.28
# 22.5 <-> 26.12
# 7.7 <-> 8.67
# 6.9 <-> 6.28
# 4.5 <-> 6.9
# 5.7 <-> 6.28
# 10.1 <-> 9.88
# 8.5 <-> 6.28
# 10.9 <-> 8.66
# 37.33 <-> 30.31
# 5.3 <-> 5.21
# 4.5 <-> 5.21
# 9.0 <-> 10.53
# 13.7 <-> 10.87
# 7.5 <-> 5.21
# 6.1 <-> 6.9
# 8.5 <-> 7.71
# 6.9 <-> 5.21
# 12.5 <-> 11.97
# 4.9 <-> 5.72
# 15.33 <-> 9.23
# 23.5 <-> 17.89
# 6.0 <-> 8.77
# 7.3 <-> 6.9
# 10.5 <-> 9.05
# 4.9 <-> 5.21
# 14.5 <-> 10.44
# 22.9 <-> 17.89
# 10.9 <-> 10.34
# 37.5 <-> 30.32
# 6.5 <-> 6.28
# 15.0 <-> 16.49
# 5.3 <-> 6.19
# 4.5 <-> 5.21
# 17.5 <-> 18.32
# 5.3 <-> 6.28
# 5.7 <-> 5.21
# 8.9 <-> 7.71
# 6.5 <-> 7.71
# 14.1 <-> 14.03
# 9.3 <-> 9.79
# 11.0 <-> 9.23
# 14.0 <-> 8.01
# 10.5 <-> 10.89
# 7.0 <-> 6.9
# 7.5 <-> 6.28
# 8.5 <-> 10.98
# 10.5 <-> 15.01
# 12.0 <-> 9.92
# 3.7 <-> 5.21
# 21.5 <-> 17.3
# 8.5 <-> 10.46
# 8.5 <-> 10.41
# 11.7 <-> 13.58
# 5.7 <-> 6.28
# 10.5 <-> 6.89
# 19.5 <-> 17.4
# 6.5 <-> 5.25
# 4.5 <-> 5.21
# 17.5 <-> 16.59
# 24.0 <-> 17.15
# 6.0 <-> 6.28
# 6.0 <-> 8.01
# 7.5 <-> 7.99
# 4.9 <-> 5.22
# 6.5 <-> 7.71
# 7.7 <-> 5.21
# 7.5 <-> 6.28
# 6.9 <-> 5.21
# 13.3 <-> 16.8
# 6.5 <-> 5.69
# 16.5 <-> 17.89
# 4.5 <-> 5.21
# 9.5 <-> 11.86
# 4.9 <-> 6.89
# 9.5 <-> 5.21
# 7.3 <-> 6.91
# 5.7 <-> 5.21
# 7.5 <-> 7.85
# 33.83 <-> 25.6
# 12.5 <-> 9.15
# 5.7 <-> 5.21
# 7.5 <-> 7.99
# 6.5 <-> 6.28
# 15.5 <-> 13.34
# 12.0 <-> 13.34
# 6.6 <-> 5.69
# 4.0 <-> 5.21
# 9.0 <-> 6.29
# 8.5 <-> 8.08
# 2.9 <-> 5.21
# 7.3 <-> 6.28
# 5.7 <-> 6.28
# 10.5 <-> 5.95
# 9.3 <-> 9.13
# 7.3 <-> 7.71
# 8.5 <-> 7.71
# 7.0 <-> 8.66
# 9.0 <-> 5.69
# 7.7 <-> 9.57
# 6.0 <-> 6.19
# 3.5 <-> 5.21
# 17.3 <-> 12.19
# 15.5 <-> 15.19
# 14.1 <-> 9.66
# 7.3 <-> 9.05
# 4.9 <-> 5.3
# 6.9 <-> 6.9
# 5.3 <-> 6.48
# 7.7 <-> 9.8
# 4.5 <-> 10.08
# 7.8 <-> 6.91
# 7.3 <-> 9.79
# 6.0 <-> 6.19
# 8.0 <-> 8.66
# 16.5 <-> 19.36
# 4.9 <-> 6.29
# 13.0 <-> 12.56
# 5.7 <-> 6.28
# 2.5 <-> 5.21
# 8.5 <-> 9.13
# 8.5 <-> 6.28
# 6.5 <-> 7.71
# 4.1 <-> 5.21
# 6.5 <-> 5.69
# 15.0 <-> 17.05
# 7.7 <-> 8.53
# 9.3 <-> 9.13
# 3.3 <-> 5.21
# 4.5 <-> 6.19
# 9.8 <-> 9.9
# 10.1 <-> 10.88
# 8.0 <-> 7.96
# 8.9 <-> 6.25
# 4.1 <-> 6.28
# 4.5 <-> 5.21
# 9.0 <-> 8.67
# 10.3 <-> 8.66
# 12.9 <-> 14.74
# 4.5 <-> 5.21
# 8.5 <-> 8.98
# 10.5 <-> 13.53
# 17.0 <-> 13.3
# 7.0 <-> 6.28
# 5.3 <-> 8.66
# 14.5 <-> 15.08
# 17.3 <-> 14.56
# 10.9 <-> 12.13
# 5.3 <-> 6.28
# 6.5 <-> 6.28
# 7.3 <-> 8.66
# 5.0 <-> 6.19
# 6.5 <-> 6.08
# 9.7 <-> 7.71
# 7.3 <-> 6.42
# 6.5 <-> 5.23
# 4.5 <-> 5.21
# 12.5 <-> 9.17
# 12.5 <-> 11.8
# 8.5 <-> 9.13
# 6.5 <-> 6.28
# 11.3 <-> 12.23
# 4.9 <-> 5.21
# 11.0 <-> 10.35
# 30.0 <-> 30.44
# 15.7 <-> 13.61
# 7.3 <-> 6.93
# 12.9 <-> 8.66
# 7.0 <-> 5.25
# 16.5 <-> 14.58
# 10.9 <-> 10.66
# 4.5 <-> 6.08
# 4.5 <-> 6.28
# 14.0 <-> 17.04
# 9.0 <-> 5.21
# 12.9 <-> 13.66
# 5.0 <-> 5.21
# 19.5 <-> 19.27
# 5.0 <-> 5.21
# 8.9 <-> 10.88
# 19.0 <-> 14.54
# 9.3 <-> 5.21
# 10.5 <-> 10.94
# 5.3 <-> 9.57
# 4.5 <-> 5.21
# 7.5 <-> 9.17
# 9.0 <-> 10.41
# 19.5 <-> 9.78
# 13.5 <-> 11.87
# 8.5 <-> 9.15
# 7.5 <-> 5.98
# 32.3 <-> 26.12
# 12.9 <-> 8.03
# 7.3 <-> 6.91
# 8.5 <-> 10.41
# 5.5 <-> 6.28
# 15.3 <-> 5.21
# 7.0 <-> 7.77
# 8.5 <-> 11.38
# 7.3 <-> 6.9
# 17.0 <-> 16.73
# 19.0 <-> 13.58
# 7.7 <-> 7.71
# 6.1 <-> 6.28
# 6.0 <-> 6.29
# 10.0 <-> 9.15
# 8.1 <-> 6.28
# 3.7 <-> 5.21
# 12.0 <-> 8.86
# 4.5 <-> 6.28
# 4.5 <-> 5.69
# 4.9 <-> 5.26
# 10.0 <-> 10.41
# 8.0 <-> 6.08
# 22.5 <-> 17.75
# 9.0 <-> 10.51
# 12.0 <-> 7.71
# 18.1 <-> 23.48
# 8.5 <-> 5.95
# 4.1 <-> 5.21
# 5.5 <-> 6.28
# 13.3 <-> 17.65
# 20.0 <-> 17.6
# 10.5 <-> 12.44
# 6.1 <-> 6.28
# 6.1 <-> 7.71
# 6.5 <-> 6.28
# 36.1 <-> 27.52
# 4.1 <-> 5.69
# 12.9 <-> 12.23
# 26.0 <-> 21.76
# 16.5 <-> 16.49
# 7.5 <-> 8.01
# 7.0 <-> 5.21
# 8.5 <-> 10.64
# 9.0 <-> 10.01
# 5.5 <-> 5.21
# 12.0 <-> 13.32
# 25.3 <-> 26.21
# 5.7 <-> 6.9
# 7.3 <-> 6.28
# 7.7 <-> 5.21
# 7.3 <-> 6.91
# 3.7 <-> 9.57
# 12.0 <-> 10.41
# 10.9 <-> 12.04
# 8.5 <-> 6.28
# 2.5 <-> 6.23
# 5.3 <-> 6.28
# 21.5 <-> 22.17
# 6.5 <-> 7.44
# 10.9 <-> 8.66
# 15.0 <-> 16.49
# 8.1 <-> 9.77
# 5.1 <-> 5.23
# 15.5 <-> 10.79
# 13.5 <-> 13.26
# 4.9 <-> 6.28
# 8.0 <-> 6.28
# 5.7 <-> 6.29
# 16.5 <-> 12.11
# 14.5 <-> 13.3
# 6.5 <-> 7.71
# 8.1 <-> 8.13
# 9.5 <-> 10.87
# 11.0 <-> 8.66
# 7.5 <-> 11.84
# 14.5 <-> 10.89
# 7.7 <-> 8.66
# 11.3 <-> 17.6
# 11.0 <-> 12.95
# 4.5 <-> 5.24
# 12.5 <-> 9.57
# 5.3 <-> 6.29
# 3.7 <-> 5.21
# 15.3 <-> 14.55
# 4.5 <-> 6.89
# 10.1 <-> 8.66
# 4.9 <-> 8.66
# 23.0 <-> 32.88
# 4.1 <-> 5.21
# 5.0 <-> 6.28
# 9.0 <-> 13.3
# 3.3 <-> 5.21
# 6.5 <-> 7.71
# 11.3 <-> 9.01
# 7.0 <-> 7.87
# 6.5 <-> 6.9
# 18.5 <-> 12.13
# 17.5 <-> 16.57
# 3.5 <-> 5.21
# 3.7 <-> 5.21
# 11.3 <-> 13.58
# 10.9 <-> 9.78
# 12.9 <-> 12.19
# 6.1 <-> 9.62
# 21.0 <-> 20.58
# 5.5 <-> 6.28
# 3.7 <-> 5.21
# 9.7 <-> 9.77
# 20.0 <-> 19.63
# 6.9 <-> 8.98
# 7.7 <-> 7.71
# 16.1 <-> 10.65
# 8.5 <-> 9.14
# 11.5 <-> 9.77
# 6.9 <-> 9.06
# 10.5 <-> 8.02
# 10.9 <-> 12.2
# 5.7 <-> 5.24
# 5.0 <-> 6.28
# 7.5 <-> 6.28
# 9.7 <-> 14.73
# 5.3 <-> 6.28
# 6.5 <-> 6.28
# 8.9 <-> 8.12
# 10.5 <-> 8.67
# 4.1 <-> 5.21
# 6.5 <-> 6.67
# 12.1 <-> 13.59
# 6.9 <-> 6.9
# 30.0 <-> 26.12
# 4.9 <-> 5.23
# 12.5 <-> 11.85
# 8.9 <-> 9.22
# 6.5 <-> 7.87
# 10.0 <-> 13.65
# 6.1 <-> 6.28
# 7.0 <-> 10.41
# 3.7 <-> 5.21
# 8.9 <-> 8.66
# 5.0 <-> 6.24
# 4.0 <-> 5.21
# 8.9 <-> 6.9
# 4.5 <-> 5.21
# 10.1 <-> 12.12
# 2.5 <-> 5.21
# 7.5 <-> 6.28
# 7.0 <-> 7.71
# 25.7 <-> 29.45
# 6.9 <-> 7.07
# 12.5 <-> 11.89
# 15.3 <-> 15.16
# 10.0 <-> 10.33
# 8.5 <-> 9.05
# 12.0 <-> 10.87
# 31.3 <-> 29.54
# 10.5 <-> 13.51
# 6.1 <-> 6.28
# 6.9 <-> 8.66
# 6.9 <-> 5.26
# 10.5 <-> 8.66
# 25.0 <-> 19.63
# 5.1 <-> 5.3
# 6.0 <-> 5.21
# 5.7 <-> 7.71
# 10.0 <-> 7.77
# 6.1 <-> 6.28
# 21.5 <-> 18.49
# 39.83 <-> 30.44
# 4.1 <-> 5.21
# 6.5 <-> 6.29
# 6.5 <-> 7.71
# 7.0 <-> 6.28
# 5.0 <-> 5.21
# 6.5 <-> 7.55
# 13.0 <-> 9.64
# 2.5 <-> 5.22
# 25.3 <-> 26.21
# 13.5 <-> 16.59
# 14.0 <-> 13.58
# 4.0 <-> 5.21
# 6.1 <-> 6.28
# 6.5 <-> 6.28
# 4.9 <-> 6.19
# 8.5 <-> 8.59
# 16.0 <-> 13.58
# 6.9 <-> 6.42
# 8.9 <-> 7.16
# 5.5 <-> 5.95
# 8.5 <-> 6.28
# 10.1 <-> 12.12
# 14.1 <-> 14.69
# 4.9 <-> 6.93
# 8.9 <-> 9.46
# 11.0 <-> 10.41
# 4.0 <-> 5.21
# 10.5 <-> 10.66
# 4.5 <-> 9.57
# 13.3 <-> 12.13
# 15.3 <-> 17.6
# 5.3 <-> 6.9
# 38.9 <-> 26.12
# 15.7 <-> 21.58
# 4.9 <-> 5.72
# 5.7 <-> 6.9
# 14.1 <-> 10.88
# 10.1 <-> 9.83
# 6.5 <-> 5.98
# 17.0 <-> 12.56
# 8.5 <-> 9.17
# 8.9 <-> 8.66
# 13.7 <-> 14.64
# 8.1 <-> 7.77
# 8.1 <-> 7.73
# 7.0 <-> 8.01
# 15.7 <-> 18.17
# 10.9 <-> 7.77
# 10.9 <-> 8.66
# 11.3 <-> 8.66
# 2.5 <-> 5.25
# 13.7 <-> 14.64
# 8.9 <-> 5.3
# 3.5 <-> 5.21
# 7.7 <-> 7.71
# 9.3 <-> 8.66
# 4.5 <-> 5.21
# 5.7 <-> 6.28
# 13.3 <-> 10.94
# 4.9 <-> 5.21
# 9.3 <-> 9.79
# 11.0 <-> 5.25
# 12.5 <-> 16.57
# 9.0 <-> 9.23
# 4.5 <-> 5.73
# 5.0 <-> 5.98
# 9.5 <-> 11.96
# 15.5 <-> 16.83
# 5.7 <-> 5.69
# 12.0 <-> 11.86
# 30.9 <-> 29.45
# 5.7 <-> 7.77
# 7.7 <-> 6.43
# 5.5 <-> 6.19
# 15.7 <-> 17.65
# 6.5 <-> 6.08
# 9.0 <-> 11.83
# 34.1 <-> 26.12
# 15.0 <-> 11.8
# 10.0 <-> 8.08
# 5.5 <-> 6.65
# 4.9 <-> 5.21
# 9.0 <-> 8.37
# 7.5 <-> 8.08
# 10.9 <-> 9.66
# 5.0 <-> 5.21
# 8.5 <-> 6.28
# 23.5 <-> 18.32
# 6.9 <-> 6.9
# 2.5 <-> 5.29
# 7.5 <-> 8.86
# 5.3 <-> 6.9
# 10.5 <-> 12.93
# 4.5 <-> 5.21
# 6.1 <-> 6.91
# 7.7 <-> 7.71
# 6.9 <-> 9.78
# 5.7 <-> 5.69
# 8.9 <-> 8.66
# 5.5 <-> 6.28
# 7.3 <-> 7.71
# 6.5 <-> 7.71
# 4.1 <-> 5.23
# 14.1 <-> 12.13
# 8.0 <-> 7.96
# 5.5 <-> 7.99
# 29.450000000000006 <-> 26.12
# 10.9 <-> 9.9
# 20.5 <-> 21.21
# 6.0 <-> 5.21
# 17.0 <-> 19.45
# 11.5 <-> 9.15
# 9.7 <-> 9.8
# 6.5 <-> 6.29
# 6.9 <-> 9.47
# 4.0 <-> 6.28
# 8.1 <-> 9.58
# 3.3 <-> 5.21
# 7.0 <-> 6.28
# 8.5 <-> 10.19
# 4.0 <-> 5.21
# 6.0 <-> 5.69
# 5.7 <-> 6.28
# 6.1 <-> 7.71
# 4.1 <-> 5.21
# 8.5 <-> 7.71
# 6.0 <-> 8.01
# 5.3 <-> 6.93
# 4.1 <-> 5.21
# 6.1 <-> 6.28
# 11.5 <-> 14.93
# 6.9 <-> 8.66
# 11.7 <-> 10.88
# 8.1 <-> 6.85
# 28.33 <-> 17.05
# 10.1 <-> 5.21
# 14.9 <-> 12.23
# 8.1 <-> 8.58
# 9.0 <-> 9.15
# 8.0 <-> 9.15
# 5.3 <-> 6.89
# 20.0 <-> 10.19
# 7.7 <-> 6.26
# 8.5 <-> 8.41
# 7.7 <-> 8.12
# 8.9 <-> 9.8
# 10.5 <-> 9.64
# 12.2 <-> 11.29
# 8.5 <-> 8.66
# 15.5 <-> 10.87
# 12.0 <-> 10.78
# 11.5 <-> 13.81
# 12.9 <-> 15.24
# 10.1 <-> 9.06
# 8.5 <-> 9.79
# 13.5 <-> 17.03
# 10.9 <-> 6.19
# 10.9 <-> 11.12
# 12.5 <-> 8.01
# 12.5 <-> 10.02
# 6.0 <-> 6.28
# 6.1 <-> 7.44
# 7.5 <-> 6.28
# 10.5 <-> 10.52
# 7.3 <-> 7.71
# 9.5 <-> 7.71
# 39.7 <-> 26.12
# 11.0 <-> 8.01
# 13.0 <-> 17.15
# 3.5 <-> 6.17
# 9.7 <-> 10.93
# 6.0 <-> 6.28
# 10.1 <-> 10.57
# 4.5 <-> 5.21
# 4.5 <-> 5.21
# 10.9 <-> 10.86
# 5.7 <-> 6.28
# 6.9 <-> 5.28
# 8.5 <-> 8.66
# 13.0 <-> 11.97
# 5.3 <-> 6.5
# 6.5 <-> 6.43
# 15.7 <-> 12.23
# 8.1 <-> 6.88
# 12.9 <-> 12.05
# 7.5 <-> 8.21
# 7.5 <-> 6.29
# 16.9 <-> 17.52
# 14.5 <-> 11.86
# 3.7 <-> 5.21
# 7.3 <-> 6.93
# 4.5 <-> 5.98
# 6.0 <-> 5.24
# 6.5 <-> 6.28
# 5.7 <-> 6.28
# 17.5 <-> 22.17
# 9.3 <-> 10.88
# 5.7 <-> 5.23
# 8.1 <-> 8.66
# 4.5 <-> 6.28
# 4.1 <-> 5.21
# 7.5 <-> 6.28
# 9.8 <-> 9.83
# 8.9 <-> 6.9
# 4.5 <-> 5.21
# 6.9 <-> 7.71
# 4.9 <-> 5.21
# 6.1 <-> 6.9
# 32.83 <-> 30.11
# 8.5 <-> 7.71
# 12.1 <-> 10.87
# 7.3 <-> 7.77
# 4.1 <-> 6.28
# 12.5 <-> 10.41
# 13.3 <-> 13.58
# 9.0 <-> 8.66
# 9.7 <-> 12.13
# 8.1 <-> 8.6
# 10.5 <-> 12.13
# 4.5 <-> 5.21
# 15.5 <-> 6.89
# 13.0 <-> 10.42
# 7.0 <-> 6.28
# 30.0 <-> 23.49
# 7.5 <-> 6.69
# 7.0 <-> 8.1
# 16.0 <-> 18.28
# 10.5 <-> 9.78
# 12.0 <-> 12.13
# 4.9 <-> 5.21
# 8.5 <-> 9.21
# 10.1 <-> 12.23
# 6.5 <-> 7.87
# 5.0 <-> 5.21
# 14.9 <-> 13.58
# 6.5 <-> 6.28
# 8.5 <-> 6.28
# 5.0 <-> 5.21
# 4.5 <-> 6.28
# 19.5 <-> 17.97
# 7.7 <-> 6.85
# 6.1 <-> 6.9
# 10.9 <-> 13.58
# 30.33 <-> 30.93
# 31.8 <-> 26.12
# 6.9 <-> 6.29
# 4.0 <-> 5.24
# 10.0 <-> 12.93
# 8.1 <-> 6.89
# 9.7 <-> 12.13
# 26.1 <-> 29.58
# 8.0 <-> 9.15
# 5.3 <-> 5.21
# 7.1 <-> 6.9
# 4.5 <-> 6.29
# 23.5 <-> 24.48
# 4.0 <-> 5.21
# 10.1 <-> 9.05
# 5.0 <-> 6.28
# 16.0 <-> 16.96
# 6.1 <-> 5.21
# 18.0 <-> 13.24
# 3.0 <-> 5.21
# 4.5 <-> 5.21
# 10.5 <-> 8.21
# 4.9 <-> 5.21
# 22.0 <-> 25.58
# 12.5 <-> 16.39
# 16.5 <-> 17.09
# 11.5 <-> 13.31
# 6.1 <-> 6.9
# 18.9 <-> 13.58
# 8.5 <-> 7.72
# 4.5 <-> 6.9
# 6.9 <-> 6.9
# 23.7 <-> 26.12
# 8.0 <-> 10.41
# 9.0 <-> 10.41
# 11.3 <-> 6.9
# 15.0 <-> 14.66
# 6.0 <-> 6.28
# 7.5 <-> 6.08
# 7.5 <-> 6.9
# 5.7 <-> 6.23
# 8.9 <-> 8.66
# 5.3 <-> 5.98
# 12.5 <-> 9.79
# 4.5 <-> 5.24
# 8.9 <-> 9.13
# 14.5 <-> 10.41
# 8.5 <-> 7.85
# 7.5 <-> 9.14
# 6.9 <-> 6.93
# 8.0 <-> 5.21
# 7.0 <-> 7.87
# 6.0 <-> 5.95
# 12.1 <-> 12.12
# 12.5 <-> 12.13
# 8.0 <-> 6.82
# 8.5 <-> 8.67
# 5.5 <-> 5.24
# 4.5 <-> 6.28
# 9.5 <-> 9.15
# 5.3 <-> 5.22
# 8.9 <-> 12.23
# 11.0 <-> 9.21
# 6.5 <-> 6.28
# 7.5 <-> 9.15
# 8.1 <-> 9.8
# 6.5 <-> 6.28
# 16.0 <-> 17.05
# 37.0 <-> 30.3
# 10.0 <-> 6.29
# 10.1 <-> 8.66
# 6.5 <-> 5.21
# 20.5 <-> 25.89
# 4.1 <-> 6.28
# 19.5 <-> 10.19
# 8.5 <-> 6.9
# 4.6 <-> 5.21
# 5.7 <-> 7.71
# 9.3 <-> 8.66
# 6.5 <-> 7.55
# 8.5 <-> 9.8
# 10.0 <-> 11.85
# 5.3 <-> 7.71
# 12.1 <-> 10.87
# 10.5 <-> 13.4
# 18.5 <-> 25.56
# 4.9 <-> 6.29
# 7.5 <-> 8.01
# 10.5 <-> 9.77
# 13.0 <-> 13.24
# 5.3 <-> 6.28
# 10.5 <-> 6.28
# 5.0 <-> 6.28
# 9.3 <-> 10.98
# 11.7 <-> 7.71
# 4.1 <-> 5.21
# 19.5 <-> 21.63
# 4.5 <-> 6.28
# 6.5 <-> 7.87
# 12.0 <-> 11.89
# 8.9 <-> 9.06
# 8.5 <-> 8.01
# 27.0 <-> 20.69
# 4.5 <-> 5.26
# 13.0 <-> 13.58
# 4.9 <-> 5.25
# 4.5 <-> 5.21
# 5.7 <-> 5.73
# 12.1 <-> 5.99
# 5.7 <-> 6.9
# 8.5 <-> 10.19
# 5.5 <-> 6.08
# 8.9 <-> 7.55
# 19.0 <-> 13.24
# 6.9 <-> 7.71
# 3.3 <-> 5.21
# 10.1 <-> 10.88
# 7.3 <-> 7.73
# 8.5 <-> 8.77
# 7.0 <-> 8.1
# 9.7 <-> 6.28
# 4.5 <-> 5.21
# 9.3 <-> 12.13
# 14.5 <-> 14.73
# 5.3 <-> 7.16
# 5.7 <-> 6.26
# 12.0 <-> 10.86
# 4.1 <-> 5.21
# 3.3 <-> 5.21
# 14.5 <-> 10.51
# 4.5 <-> 5.24
# 5.7 <-> 6.29
# 4.0 <-> 5.21
# 7.7 <-> 6.9
# 10.0 <-> 9.15
# 13.7 <-> 15.22
# 9.7 <-> 12.13
# 12.0 <-> 10.55
# 7.7 <-> 7.71
# 18.5 <-> 17.43
# 20.0 <-> 22.02
# 12.9 <-> 9.92
# 5.7 <-> 5.21
# 10.0 <-> 10.35
# 8.5 <-> 9.6
# 5.3 <-> 6.19
# 17.3 <-> 21.61
# 24.0 <-> 18.28
# 4.9 <-> 5.21
# 8.1 <-> 9.78
# 13.0 <-> 20.55
# 8.1 <-> 9.8
# 8.9 <-> 10.98
# 29.5 <-> 33.0
# 10.5 <-> 10.42
# 5.3 <-> 6.19
# 6.9 <-> 6.9
# 19.5 <-> 13.3
# 4.9 <-> 6.24
# 4.9 <-> 5.21
# 6.5 <-> 5.21
# 19.5 <-> 19.39
# 12.1 <-> 7.71
# 4.5 <-> 5.24
# 12.5 <-> 13.58
# 11.0 <-> 12.56
# 8.5 <-> 8.01
# 5.3 <-> 7.71
# 18.0 <-> 17.97
# 11.7 <-> 10.89
# 16.5 <-> 16.49
# 6.6 <-> 6.91
# 7.0 <-> 6.89
# 5.0 <-> 5.21
# 6.5 <-> 7.71
# 8.0 <-> 5.21
# 13.0 <-> 9.15
# 8.5 <-> 8.66
# 6.5 <-> 6.29
# 4.5 <-> 6.28
# 6.5 <-> 5.66
# 8.9 <-> 12.13
# 10.5 <-> 10.42
# 9.3 <-> 13.48
# 6.1 <-> 6.9
# 7.3 <-> 5.25
# 4.1 <-> 5.21
# 5.0 <-> 6.28
# 11.3 <-> 14.74
# 10.5 <-> 10.44
# 6.9 <-> 9.8
# 9.7 <-> 12.13
# 7.3 <-> 8.66
# 8.1 <-> 6.91
# 5.5 <-> 10.24
# 10.9 <-> 14.57
# 11.7 <-> 17.6
# 7.5 <-> 6.28
# 14.0 <-> 6.28
# 25.5 <-> 30.12
# 10.0 <-> 10.08
# 8.5 <-> 6.9
# 3.7 <-> 5.24
# 6.1 <-> 6.89
# 20.5 <-> 16.8
# 10.1 <-> 13.57
# 4.9 <-> 6.26
# 6.0 <-> 6.28
# 17.3 <-> 13.7
# 14.5 <-> 11.83
# 11.5 <-> 6.28
# 4.5 <-> 5.21
# 10.9 <-> 12.13
# 8.5 <-> 7.71
# 4.5 <-> 5.21
# 12.5 <-> 8.93
# 10.1 <-> 8.67
# 18.5 <-> 19.5
# 32.0 <-> 26.12
# 14.5 <-> 13.26
# 6.1 <-> 6.9
# 6.9 <-> 7.71
# 18.0 <-> 13.26
# 11.5 <-> 11.84
# 8.9 <-> 8.67
# 9.0 <-> 5.21
# 20.9 <-> 18.87
# 4.9 <-> 6.19
# 19.0 <-> 13.26
# 5.7 <-> 6.28
# 4.5 <-> 5.21
# 10.1 <-> 12.11
# 7.7 <-> 8.66
# 8.1 <-> 8.66
# 5.3 <-> 6.28
# 4.5 <-> 5.21
# 11.7 <-> 15.18
# 8.0 <-> 6.28
# 11.3 <-> 12.58
# 12.1 <-> 13.58
# 18.0 <-> 17.6
# 10.1 <-> 10.86
# 4.5 <-> 6.28
# 26.9 <-> 23.51
# 6.5 <-> 6.28
# 6.1 <-> 7.71
# 8.7 <-> 7.07
# 17.5 <-> 16.91
# 15.3 <-> 15.16
# 14.5 <-> 16.32
# 13.3 <-> 15.23
# 4.1 <-> 5.21
# 16.0 <-> 17.03
# 3.5 <-> 5.21
# 14.0 <-> 10.41
# 7.0 <-> 10.26
# 4.9 <-> 6.9
# 25.0 <-> 21.76
# 5.3 <-> 5.3
# 13.7 <-> 9.16
# 5.3 <-> 6.9
# 7.7 <-> 8.12
# 10.0 <-> 9.78
# 10.5 <-> 11.84
# 12.9 <-> 6.88
# 3.5 <-> 10.19
# 8.5 <-> 9.14
# 4.1 <-> 5.24
# 5.7 <-> 5.21
# 5.7 <-> 7.1
# 9.7 <-> 6.9
# 16.5 <-> 20.58
# 5.3 <-> 6.28
# 7.5 <-> 7.85
# 10.5 <-> 12.23
# 6.5 <-> 6.28
# 9.7 <-> 11.75
# 16.5 <-> 15.78
# 33.0 <-> 29.89
# 9.5 <-> 6.28
# 4.5 <-> 6.42
# 4.9 <-> 15.18
# 7.3 <-> 8.66
# 5.5 <-> 6.28
# 7.3 <-> 6.19
# 7.7 <-> 9.16
# 3.3 <-> 5.21
# 7.7 <-> 10.51
# 8.0 <-> 9.02
# 10.1 <-> 10.04
# 8.1 <-> 7.07
# 9.0 <-> 8.66
# 10.5 <-> 9.06
# 10.5 <-> 12.13
# 8.9 <-> 12.13
# 10.0 <-> 10.41
# 5.7 <-> 5.24
# 4.5 <-> 6.28
# 11.0 <-> 12.58
# 8.5 <-> 9.18
# 2.9 <-> 5.21
# 27.0 <-> 28.02
# 6.5 <-> 8.01
# 10.1 <-> 9.23
# 4.9 <-> 6.9
# 22.5 <-> 29.8
# 6.0 <-> 9.15
# 6.5 <-> 6.28
# 7.3 <-> 8.66
# 6.1 <-> 6.82
# 8.5 <-> 9.83
# 7.3 <-> 6.84
# 6.5 <-> 7.1
# 10.5 <-> 8.01
# 3.0 <-> 5.22
# 8.1 <-> 9.57
# 8.0 <-> 6.28
# 7.3 <-> 7.16
# 8.1 <-> 8.66
# 19.5 <-> 19.71
# 7.0 <-> 7.71
# 4.1 <-> 6.24
# 11.7 <-> 12.13
# 11.7 <-> 8.06
# 9.7 <-> 5.21
# 6.0 <-> 6.08
# 2.9 <-> 5.21
# 4.1 <-> 6.23
# 11.5 <-> 9.15
# 15.7 <-> 13.58
# 3.7 <-> 5.21
# 17.5 <-> 17.05
# 8.5 <-> 5.28
# 6.5 <-> 7.71
# 10.1 <-> 9.65
# 7.5 <-> 10.41
# 5.3 <-> 6.89
# 13.45 <-> 9.78
# 8.9 <-> 7.44
# 7.7 <-> 5.22
# 9.5 <-> 9.21
# 8.9 <-> 8.66
# 26.1 <-> 23.48
# 9.7 <-> 6.9
# 16.9 <-> 17.55
# 13.5 <-> 11.84
# 8.5 <-> 7.55
# 13.7 <-> 11.38
# 7.0 <-> 9.15
# 12.0 <-> 7.71
# 4.5 <-> 5.21
# 5.7 <-> 8.6
# 10.0 <-> 9.14
# 5.3 <-> 6.42
# 6.5 <-> 6.28
# 7.3 <-> 6.84
# 4.9 <-> 5.24
# 18.0 <-> 16.96
# 6.5 <-> 7.71
# 4.1 <-> 5.69
# 8.0 <-> 9.14
# 6.5 <-> 6.28
# 4.9 <-> 6.28
# 5.5 <-> 6.28
# 12.1 <-> 9.65
# 14.9 <-> 10.88
# 4.5 <-> 5.21
# 18.5 <-> 13.62
# 7.3 <-> 10.01
# 6.1 <-> 5.21
# 6.1 <-> 6.89
# 9.5 <-> 8.08
# 31.8 <-> 26.16
# 5.3 <-> 6.28
# 7.7 <-> 8.66
# 9.5 <-> 12.12
# 11.3 <-> 10.66
# 4.5 <-> 5.3
# 14.9 <-> 12.58
# 12.5 <-> 14.56
# 10.5 <-> 6.9
# 11.7 <-> 12.13
# 11.3 <-> 10.88
# 7.0 <-> 7.85
# 8.9 <-> 10.89
# 7.7 <-> 9.83
# 4.5 <-> 6.28
# 5.3 <-> 5.6
# 6.9 <-> 9.89
# 6.1 <-> 6.9
# 17.7 <-> 21.58
# 9.0 <-> 10.41
# 13.3 <-> 13.66
# 5.3 <-> 7.16
# 5.3 <-> 6.28
# 4.5 <-> 5.21
# 8.5 <-> 7.71
# 6.5 <-> 7.71
# 15.5 <-> 13.28
# 35.0 <-> 26.12
# 9.5 <-> 6.9
# 7.7 <-> 7.71
# 14.0 <-> 11.89
# 7.7 <-> 8.59
# 9.7 <-> 8.67
# 4.1 <-> 5.21
# 8.1 <-> 9.46
# 6.5 <-> 5.69
# 11.3 <-> 9.89
# 4.1 <-> 6.28
# 36.25 <-> 29.58
# 7.0 <-> 10.51
# 4.9 <-> 6.28
# 12.1 <-> 14.76
# 11.5 <-> 10.44
# 11.3 <-> 10.93
# 5.0 <-> 5.24
# 9.5 <-> 10.41
# 14.0 <-> 10.41
# 6.5 <-> 6.28
# 8.1 <-> 8.66
# 11.0 <-> 10.41
# 12.0 <-> 9.13
# 18.0 <-> 18.27
# 6.5 <-> 6.28
# 18.9 <-> 9.9
# 8.5 <-> 10.65
# 12.0 <-> 11.81
# 5.5 <-> 6.28
# 14.0 <-> 10.87
# 33.0 <-> 30.61
# 32.1 <-> 29.58
# 4.5 <-> 5.21
# 4.1 <-> 5.22
# 8.5 <-> 8.59
# 12.1 <-> 12.13
# 12.0 <-> 11.84
# 5.0 <-> 6.28
# 4.1 <-> 5.21
# 5.0 <-> 5.21
# 12.0 <-> 11.89
# 4.5 <-> 5.22
# 13.7 <-> 14.73
# 12.0 <-> 10.41
# 12.9 <-> 12.08
# 13.0 <-> 10.42
# 6.1 <-> 6.28
# 7.0 <-> 7.35
# 11.7 <-> 9.78
# 6.9 <-> 6.9
# 7.5 <-> 8.54
# 5.0 <-> 5.21
# 5.0 <-> 5.21
# 7.0 <-> 5.28
# 6.9 <-> 6.9
# 6.0 <-> 6.28
# 8.0 <-> 8.01
# 6.9 <-> 8.66
# 4.1 <-> 5.25
# 11.0 <-> 11.84
# 11.5 <-> 15.01
# 15.3 <-> 9.88
# 15.7 <-> 13.65
# 6.5 <-> 6.85
# 6.5 <-> 6.93
# 6.5 <-> 5.24
# 6.5 <-> 6.28
# 6.5 <-> 7.71
# 34.5 <-> 21.58
# 5.5 <-> 5.21
# 8.9 <-> 12.2
# 6.5 <-> 5.26
# 6.9 <-> 5.24
# 8.0 <-> 6.9
# 14.9 <-> 13.57
# 12.5 <-> 12.58
# 27.0 <-> 15.12
# 4.9 <-> 7.71
# 4.9 <-> 6.19
# 6.9 <-> 7.71
# 10.0 <-> 10.44
# 16.1 <-> 13.74
# 9.5 <-> 10.31
# 7.0 <-> 6.28
# 4.0 <-> 5.21
# 7.3 <-> 7.85
# 5.7 <-> 9.57
# 8.5 <-> 6.28
# 16.5 <-> 13.68
# 20.1 <-> 14.59
# 21.7 <-> 25.79
# 6.1 <-> 6.24
# 14.9 <-> 6.24
# 11.3 <-> 12.13
# 11.5 <-> 11.87
# 8.0 <-> 6.28
# 8.9 <-> 10.87
# 27.07 <-> 27.2
# 12.0 <-> 10.34
# 11.5 <-> 9.6
# 6.0 <-> 7.85
# 5.3 <-> 7.71
# 8.0 <-> 11.87
# 6.0 <-> 8.01
# 4.5 <-> 5.21
# 36.83 <-> 30.3
# 8.1 <-> 9.47
# 9.5 <-> 10.43
# 36.5 <-> 29.58
# 8.5 <-> 10.44
# 7.5 <-> 10.41
# 5.3 <-> 7.44
# 6.5 <-> 6.9
# 10.0 <-> 9.23
# 3.7 <-> 5.21
# 4.9 <-> 6.28
# 7.7 <-> 9.83
# 5.3 <-> 6.28
# 8.5 <-> 5.21
# 9.3 <-> 12.13
# 9.0 <-> 8.08
# 8.5 <-> 9.78
# 9.3 <-> 7.71
# 8.9 <-> 10.51
# 7.5 <-> 6.65
# 9.5 <-> 9.17
# 3.7 <-> 5.21
# 7.7 <-> 8.66
# 6.1 <-> 6.9
# 14.5 <-> 10.36
# 19.3 <-> 21.58
# 16.0 <-> 6.23
# 10.5 <-> 10.36
# 8.1 <-> 7.07
# 5.3 <-> 6.9
# 6.5 <-> 7.72
# 5.3 <-> 6.85
# 6.0 <-> 5.21
# 10.5 <-> 9.13
# 25.3 <-> 26.12
# 7.0 <-> 9.15
# 7.7 <-> 6.9
# 33.05 <-> 26.12
# 10.5 <-> 8.66
# 15.33 <-> 7.77
# 12.0 <-> 11.97
# 7.0 <-> 7.71
# 9.3 <-> 7.73
# 6.5 <-> 6.85
# 11.5 <-> 13.26
# 9.3 <-> 8.58
# 13.3 <-> 13.58
# 5.0 <-> 5.24
# 34.9 <-> 26.12
# 6.5 <-> 7.99
# 7.7 <-> 8.59
# 12.5 <-> 16.8
# 10.5 <-> 9.78
# 7.5 <-> 6.28
# 6.5 <-> 6.28
# 39.8 <-> 29.58
# 18.0 <-> 21.63
# 4.0 <-> 5.21
# 9.0 <-> 9.14
# 14.0 <-> 10.88
# 9.3 <-> 8.66
# 6.1 <-> 7.16
# 7.7 <-> 7.71
# 8.5 <-> 6.28
# 8.5 <-> 7.71
# 18.1 <-> 21.65
# 12.1 <-> 13.59
# 7.3 <-> 7.44
# 8.9 <-> 8.58
# 5.3 <-> 5.21
# 11.7 <-> 17.6
# 6.5 <-> 6.85
# 4.1 <-> 6.28
# 8.5 <-> 10.42
# 10.1 <-> 7.71
# 6.5 <-> 6.5
# 12.5 <-> 9.78
# 18.0 <-> 10.87
# 14.5 <-> 13.26
# 6.5 <-> 5.21
# 9.3 <-> 9.66
# 10.9 <-> 7.71
# 5.0 <-> 6.24
# 14.0 <-> 14.2
# 5.5 <-> 7.77
# 12.5 <-> 10.42
# 6.5 <-> 6.28
# 10.5 <-> 10.44
# 14.9 <-> 10.87
# 15.7 <-> 13.58
# 9.5 <-> 11.8
# 4.5 <-> 5.21
# 5.7 <-> 7.71
# 6.1 <-> 7.71
# 10.5 <-> 10.98
# 13.5 <-> 10.89
# 5.9 <-> 5.21
# 16.0 <-> 13.86
# 8.5 <-> 9.6
# 6.5 <-> 5.95
# 6.1 <-> 5.69
# 4.5 <-> 5.21
# 15.0 <-> 10.19
# 8.5 <-> 8.77
# 17.0 <-> 17.89
# 8.5 <-> 11.0
# 10.5 <-> 10.42
# 15.0 <-> 18.13
# 10.0 <-> 9.15
# 8.1 <-> 7.77
# 11.5 <-> 9.15
# 17.0 <-> 11.87
# 8.9 <-> 8.6
# 6.5 <-> 9.13
# 5.5 <-> 7.85
# 10.5 <-> 12.0
# 4.9 <-> 6.5
# 6.0 <-> 5.21
# 12.5 <-> 9.16
# 4.9 <-> 6.28
# 9.3 <-> 10.87
# 4.5 <-> 5.21
# 7.3 <-> 7.16
# 6.1 <-> 5.21
# 12.0 <-> 13.26
# 5.3 <-> 6.28
# 7.5 <-> 6.28
# 7.0 <-> 6.28
# 13.7 <-> 17.85
# 7.5 <-> 10.33
# 14.9 <-> 18.13
# 5.7 <-> 6.28
# 21.7 <-> 25.89
# 3.7 <-> 5.21
# 5.7 <-> 7.71
# 5.3 <-> 6.28
# 15.0 <-> 13.26
# 4.9 <-> 5.21
# 34.0 <-> 29.89
# 4.9 <-> 6.28
# 10.9 <-> 9.16
# 23.3 <-> 29.45
# 6.1 <-> 6.88
# 8.0 <-> 10.32
# 5.3 <-> 5.21
# 8.1 <-> 10.87
# 14.1 <-> 14.25
# 27.0 <-> 32.87
# 11.7 <-> 13.58
# 10.5 <-> 9.88
# 8.5 <-> 9.14
# 5.0 <-> 6.29
# 6.1 <-> 6.26
# 4.5 <-> 5.24
# 11.5 <-> 13.26
# 11.5 <-> 12.56
# 6.5 <-> 7.96
# 10.0 <-> 8.01
# 6.0 <-> 6.28
# 16.0 <-> 17.04
# 7.0 <-> 6.28
# 8.1 <-> 8.66
# 9.3 <-> 9.06
# 15.0 <-> 15.02
# 15.7 <-> 16.93
# 3.7 <-> 5.21
# 7.3 <-> 7.44
# 8.5 <-> 9.15
# 9.0 <-> 8.66
# 7.3 <-> 8.66
# 4.9 <-> 7.71
# 9.3 <-> 7.71
# 5.0 <-> 8.08
# 11.5 <-> 11.83
# 8.5 <-> 9.92
# 8.9 <-> 8.67
# 6.1 <-> 6.28
# 6.5 <-> 9.14
# 7.7 <-> 6.28
# 15.7 <-> 13.58
# 6.2 <-> 6.9
# 10.1 <-> 12.13
# 7.0 <-> 6.29
# 9.3 <-> 7.76
# 14.5 <-> 8.93
# 5.3 <-> 6.28
# 18.9 <-> 10.01
# 7.7 <-> 8.66
# 3.7 <-> 5.21
# 5.7 <-> 6.28
# 7.3 <-> 6.91
# 9.7 <-> 6.23
# 9.0 <-> 9.15
# 5.5 <-> 6.28
# 4.1 <-> 5.24
# 6.9 <-> 6.9
# 5.3 <-> 5.42
# 10.5 <-> 8.66
# 4.9 <-> 6.28
# 34.33 <-> 32.96
# 4.1 <-> 5.21
# 10.0 <-> 8.33
# 5.7 <-> 6.9
# 15.3 <-> 14.03
# 4.0 <-> 5.3
# 7.7 <-> 9.8
# 8.0 <-> 12.0
# 4.1 <-> 5.66
# 4.9 <-> 6.28
# 8.0 <-> 8.01
# 9.3 <-> 9.06
# 4.9 <-> 5.95
# 4.9 <-> 5.69
# 20.0 <-> 17.26
# 3.5 <-> 5.21
# 4.1 <-> 6.89
# 4.5 <-> 6.19
# 5.7 <-> 6.28
# 4.5 <-> 5.21
# 7.5 <-> 5.21
# 6.5 <-> 6.28
# 20.0 <-> 19.63
# 3.5 <-> 5.21
# 5.3 <-> 5.21
# 4.9 <-> 6.28
# 5.5 <-> 5.69
# 9.3 <-> 9.81
# 16.0 <-> 15.02
# 28.5 <-> 26.12
# 7.3 <-> 6.28
# 26.5 <-> 25.56
# 8.5 <-> 6.28
# 8.1 <-> 10.8
# 11.5 <-> 9.15
# 4.5 <-> 5.21
# 10.5 <-> 9.15
# 7.7 <-> 9.06
# 5.7 <-> 6.5
# 6.5 <-> 6.9
# 10.0 <-> 9.15
# 8.0 <-> 9.73
# 12.5 <-> 12.13
# 9.0 <-> 12.56
# 13.5 <-> 15.02
# 4.1 <-> 6.23
# 16.1 <-> 17.85
# 7.7 <-> 7.71
# 9.5 <-> 10.44
# 5.3 <-> 6.28
# 11.0 <-> 9.83
# 6.1 <-> 6.5
# 15.7 <-> 17.82
# 5.7 <-> 6.28
# 3.7 <-> 5.21
# 4.5 <-> 5.28
# 8.5 <-> 10.78
# 10.0 <-> 8.01
# 5.7 <-> 6.28
# 21.0 <-> 17.6
# 7.7 <-> 8.66
# 4.1 <-> 5.21
# 7.7 <-> 9.22
# 8.1 <-> 8.66
# 4.5 <-> 6.28
# 8.5 <-> 9.15
# 9.3 <-> 8.67
# 3.3 <-> 5.21
# 4.5 <-> 5.21
# 14.9 <-> 14.25
# 15.0 <-> 16.7
# 8.1 <-> 10.94
# 16.9 <-> 17.89
# 16.0 <-> 18.32
# 5.3 <-> 5.6
# 11.0 <-> 6.31
# 33.33 <-> 31.77
# 9.0 <-> 10.01
# 10.5 <-> 9.15
# 4.9 <-> 5.21
# 7.3 <-> 8.58
# 10.9 <-> 12.11
# 4.0 <-> 5.21
# 21.0 <-> 16.96
# 5.7 <-> 6.89
# 10.0 <-> 10.42
# 10.1 <-> 7.71
# 6.1 <-> 8.66
# 8.9 <-> 11.0
# 9.7 <-> 12.19
# 3.7 <-> 5.21
# 6.5 <-> 6.28
# 10.5 <-> 8.93
# 6.9 <-> 9.21
# 5.7 <-> 9.57
# 19.0 <-> 19.39
# 11.7 <-> 12.19
# 4.9 <-> 6.82
# 8.9 <-> 13.56
# 5.7 <-> 8.66
# 21.5 <-> 20.53
# 10.5 <-> 9.9
# 12.1 <-> 9.13
# 8.9 <-> 9.8
# 34.8 <-> 32.96
# 7.0 <-> 6.29
# 9.0 <-> 12.56
# 11.5 <-> 10.41
# 2.5 <-> 6.25
# 6.5 <-> 7.71
# 6.5 <-> 6.91
# 6.5 <-> 7.71
# 9.0 <-> 9.15
# 6.9 <-> 7.44
# 6.1 <-> 6.9
# 9.3 <-> 8.66
# 4.5 <-> 5.21
# 8.1 <-> 5.43
# 10.5 <-> 9.81
# 5.5 <-> 6.28
# 5.7 <-> 6.28
# 10.5 <-> 9.15
# 7.0 <-> 7.99
# 8.5 <-> 9.21
# 14.3 <-> 10.07
# 5.3 <-> 6.28
# 3.3 <-> 5.21
# 17.0 <-> 17.16
# 11.0 <-> 8.77
# 4.9 <-> 9.66
# 5.3 <-> 6.85
# 9.0 <-> 10.19
# 33.44 <-> 30.75
# 4.0 <-> 5.21
# 17.5 <-> 19.3
# 14.5 <-> 12.58
# 10.9 <-> 12.09
# 8.9 <-> 9.79
# 6.9 <-> 7.71
# 29.0 <-> 32.88
# 7.5 <-> 8.1
# 5.3 <-> 5.21
# 4.5 <-> 5.21
# 13.5 <-> 10.87
# 8.5 <-> 9.05
# 7.0 <-> 9.14
# 7.5 <-> 6.28
# 8.0 <-> 12.56
# 10.0 <-> 10.51
# 7.5 <-> 9.15
# 11.0 <-> 10.42
# 5.7 <-> 6.28
# 6.5 <-> 6.23
# 10.5 <-> 11.84
# 27.0 <-> 8.08
# 8.1 <-> 6.82
# 8.5 <-> 9.89
# 7.7 <-> 8.66
# 4.9 <-> 6.24
# 14.1 <-> 14.58
# 11.0 <-> 11.8
# 5.7 <-> 6.19
# 8.9 <-> 6.29
# 10.0 <-> 10.51
# 6.5 <-> 6.19
# 4.9 <-> 6.28
# 14.1 <-> 12.23
# 5.5 <-> 6.28
# 5.5 <-> 6.28
# 13.3 <-> 10.87
# 13.5 <-> 9.15
# 14.9 <-> 12.44
# 18.0 <-> 15.12
# 8.5 <-> 8.66
# 6.5 <-> 6.28
# 13.3 <-> 13.58
# 8.9 <-> 7.71
# 10.5 <-> 7.77
# 5.3 <-> 6.9
# 11.5 <-> 7.71
# 4.9 <-> 5.21
# 3.3 <-> 5.21
# 11.3 <-> 13.57
# 6.5 <-> 7.99
# 8.0 <-> 8.08
# 7.5 <-> 5.21
# 11.5 <-> 10.42
# 5.0 <-> 6.28
# 10.0 <-> 11.86
# 6.0 <-> 8.01
# 4.9 <-> 6.89
# 7.3 <-> 9.78
# 14.1 <-> 17.62
# 6.1 <-> 6.28
# 5.0 <-> 6.28
# 4.5 <-> 5.21
# 25.3 <-> 26.12
# 17.3 <-> 15.16
# 27.5 <-> 23.17
# 10.0 <-> 10.51
# 6.0 <-> 7.87
# 9.7 <-> 9.81
# 10.5 <-> 11.89
# 5.0 <-> 5.21
# 6.9 <-> 9.23
# 11.3 <-> 9.9
# 6.5 <-> 7.71
# 11.3 <-> 12.11
# 11.7 <-> 13.73
# 32.27 <-> 28.39
# 6.1 <-> 6.9
# 33.0 <-> 33.2
# 22.0 <-> 17.82
# 12.1 <-> 13.58
# 6.1 <-> 6.24
# 14.5 <-> 16.4
# 8.1 <-> 7.55
# 14.9 <-> 10.87
# 4.0 <-> 5.21
# 18.5 <-> 16.48
# 21.0 <-> 18.27
# 3.5 <-> 5.21
# 12.5 <-> 13.46
# 9.7 <-> 9.8
# 10.1 <-> 10.88
# 12.5 <-> 13.26
# 11.3 <-> 9.9
# 18.5 <-> 18.49
# 31.5 <-> 30.44
# 17.0 <-> 17.86
# 8.9 <-> 8.58
# 8.1 <-> 6.28
# 9.5 <-> 11.86
# 7.7 <-> 8.66
# 8.9 <-> 8.67
# 10.1 <-> 13.74
# 8.5 <-> 8.01
# 6.5 <-> 7.77
# 6.9 <-> 8.66
# 3.7 <-> 5.21
# 8.5 <-> 6.45
# 12.9 <-> 13.58
# 13.7 <-> 8.66
# 18.0 <-> 19.72
# 9.7 <-> 9.77
# 4.9 <-> 6.28
# 4.5 <-> 6.28
# 7.5 <-> 8.08
# 9.5 <-> 11.89
# 11.3 <-> 10.66
# 7.7 <-> 7.16
# 12.1 <-> 10.98
# 10.0 <-> 9.9
# 5.7 <-> 6.28
# 12.5 <-> 12.23
# 8.5 <-> 7.99
# 13.0 <-> 15.18
# 14.0 <-> 16.99
# 10.5 <-> 13.26
# 32.0 <-> 33.29
# 7.0 <-> 9.15
# 7.7 <-> 6.9
# 6.9 <-> 7.73
# 7.0 <-> 7.35
# 6.9 <-> 7.72
# 6.5 <-> 8.13
# 8.9 <-> 9.8
# 6.5 <-> 7.71
# 6.5 <-> 13.35
# 4.5 <-> 5.25
# 10.5 <-> 10.41
# 13.1 <-> 13.45
# 15.7 <-> 17.61
# 12.5 <-> 13.26
# 6.5 <-> 7.07
# 8.5 <-> 9.79
# 7.5 <-> 7.96
# 6.1 <-> 7.44
# 36.8 <-> 25.44
# 4.9 <-> 6.08
# 7.5 <-> 8.41
# 6.5 <-> 7.77
# 15.3 <-> 15.29
# 8.5 <-> 9.22
# 5.3 <-> 6.24
# 5.0 <-> 5.26
# 6.1 <-> 7.77
# 6.0 <-> 5.95
# 6.0 <-> 8.93
# 6.1 <-> 6.89
# 13.3 <-> 13.58
# 7.3 <-> 9.65
# 20.0 <-> 19.39
# 8.5 <-> 9.66
# 10.9 <-> 5.21
# 8.0 <-> 6.28
# 8.1 <-> 8.66
# 16.0 <-> 11.84
# 17.5 <-> 15.7
# 6.5 <-> 8.02
# 8.9 <-> 8.66
# 10.5 <-> 10.34
# 13.3 <-> 16.89
# 6.0 <-> 6.28
# 6.5 <-> 6.28
# 10.9 <-> 9.89
# 12.1 <-> 11.46
# 4.5 <-> 6.28
# 10.1 <-> 10.88
# 8.5 <-> 8.01
# 4.5 <-> 6.28
# 5.0 <-> 5.21
# 7.7 <-> 8.66
# 8.5 <-> 8.34
# 4.9 <-> 6.28
# 13.5 <-> 11.86
# 6.1 <-> 6.9
# 7.7 <-> 10.36
# 4.5 <-> 6.28
# 4.9 <-> 6.28
# 4.5 <-> 5.21
# 4.1 <-> 5.21
# 10.0 <-> 11.86
# 6.9 <-> 6.23
# 25.7 <-> 26.12
# 6.1 <-> 6.19
# 6.1 <-> 6.28
# 11.8 <-> 10.8
# 9.7 <-> 7.77
# 15.0 <-> 14.54
# 17.5 <-> 17.16
# 10.1 <-> 9.06
# 8.1 <-> 8.06
# 6.5 <-> 6.9
# 16.0 <-> 13.32
# 9.3 <-> 12.13
# 12.1 <-> 8.66
# 10.0 <-> 8.1
# 6.9 <-> 7.16
# 11.3 <-> 12.13
# 3.3 <-> 5.21
# 22.9 <-> 21.58
# 13.0 <-> 12.12
# 11.0 <-> 9.23
# 12.5 <-> 16.8
# 4.9 <-> 5.21
# 3.3 <-> 5.21
# 4.0 <-> 5.21
# 4.9 <-> 5.21
# 6.0 <-> 5.3
# 8.5 <-> 6.91
# 5.0 <-> 6.28
# 8.9 <-> 10.98
# 17.5 <-> 17.14
# 6.5 <-> 6.88
# 5.3 <-> 5.21
# 4.5 <-> 6.28
# 6.9 <-> 6.9
# 16.5 <-> 17.82
# 8.5 <-> 10.13
# 8.9 <-> 10.87
# 6.9 <-> 6.29
# 8.9 <-> 9.06
# 4.9 <-> 5.28
# 6.1 <-> 5.98
# 10.9 <-> 10.88
# 28.5 <-> 26.12
# 26.0 <-> 18.33
# 14.5 <-> 8.54
# 9.3 <-> 12.58
# 5.5 <-> 6.28
# 6.1 <-> 6.82
# 4.0 <-> 5.21
# 5.5 <-> 5.69
# 6.1 <-> 6.08
# 18.5 <-> 25.55
# 10.9 <-> 8.66
# 23.0 <-> 6.23
# 7.0 <-> 7.99
# 8.0 <-> 10.33
# 12.5 <-> 13.26
# 7.0 <-> 6.29
# 12.9 <-> 15.28
# 6.1 <-> 7.71
# 12.0 <-> 11.86
# 12.5 <-> 17.62
# 6.5 <-> 5.72
# 5.7 <-> 6.28
# 7.4 <-> 6.23
# 27.7 <-> 17.61
# 7.7 <-> 8.66
# 4.5 <-> 6.28
# 20.5 <-> 20.55
# 20.5 <-> 10.93
# 6.5 <-> 6.9
# 16.5 <-> 18.27
# 14.0 <-> 13.65
# 6.5 <-> 5.21
# 16.9 <-> 7.71
# 3.3 <-> 5.21
# 21.7 <-> 12.13
# 5.7 <-> 6.29
# 13.3 <-> 14.74
# 6.5 <-> 7.71
# 8.5 <-> 10.41
# 33.33 <-> 32.96
# 23.0 <-> 20.69
# 16.9 <-> 18.59
# 9.7 <-> 9.22
# 6.1 <-> 5.72
# 4.0 <-> 5.24
# 5.3 <-> 5.21
# 7.0 <-> 6.28
# 7.7 <-> 10.87
# 10.5 <-> 6.28
# 15.0 <-> 16.96
# 16.1 <-> 17.85
# 8.5 <-> 10.19
# 6.9 <-> 8.53
# 14.5 <-> 13.61
# 14.1 <-> 14.56
# 6.0 <-> 6.28
# 6.5 <-> 6.28
# 6.1 <-> 8.12
# 14.5 <-> 21.52
# 3.7 <-> 6.28
# 9.5 <-> 12.56
# 12.1 <-> 9.06
# 8.9 <-> 10.98
# 12.9 <-> 9.83
# 4.1 <-> 5.21
# 14.0 <-> 15.02
# 10.5 <-> 10.8
# 4.5 <-> 6.28
# 20.1 <-> 6.23
# 6.1 <-> 7.71
# 4.1 <-> 5.22
# 11.0 <-> 9.14
# 26.9 <-> 22.61
# 4.5 <-> 5.21
# 6.5 <-> 7.99
# 6.5 <-> 6.9
# 11.0 <-> 11.84
# 7.0 <-> 5.98
# 13.0 <-> 11.81
# 7.0 <-> 6.28
# 15.3 <-> 14.71
# 5.0 <-> 10.19
# 11.7 <-> 14.74
# 7.7 <-> 7.71
# 6.9 <-> 8.6
# 6.9 <-> 9.66
# 5.0 <-> 5.21
# 4.5 <-> 5.21
# 4.1 <-> 5.21
# 16.9 <-> 16.99
# 8.1 <-> 9.79
# 23.5 <-> 17.73
# 11.5 <-> 10.41
# 12.0 <-> 14.04
# 6.5 <-> 5.21
# 5.5 <-> 8.01
# 12.0 <-> 17.42
# 7.7 <-> 6.28
# 16.0 <-> 9.22
# 7.7 <-> 6.28
# 4.5 <-> 5.21
# 18.9 <-> 25.89
# 6.5 <-> 8.01
# 15.5 <-> 14.04
# 9.7 <-> 10.87
# 10.0 <-> 9.17
# 15.7 <-> 21.58
# 14.0 <-> 10.51
# 16.9 <-> 22.11
# 7.5 <-> 8.41
# 9.5 <-> 9.77
# 5.3 <-> 6.9
# 12.6 <-> 10.87
# 4.9 <-> 5.72
# 27.5 <-> 30.44
# 8.5 <-> 6.67
# 10.1 <-> 6.93
# 6.5 <-> 8.08
# 10.9 <-> 8.58
# 16.5 <-> 13.26
# 11.3 <-> 12.13
# 9.3 <-> 8.66
# 18.0 <-> 13.26
# 18.0 <-> 16.67
# 16.5 <-> 16.99
# 8.9 <-> 7.71
# 15.5 <-> 11.86
# 26.1 <-> 25.44
# 24.5 <-> 18.28
# 6.1 <-> 8.67
# 6.1 <-> 6.29
# 4.5 <-> 5.28
# 10.1 <-> 8.98
# 8.5 <-> 8.01
# 15.5 <-> 17.05
# 7.5 <-> 6.89
# 6.5 <-> 6.23
# 10.9 <-> 10.36
# 6.5 <-> 5.58
# 21.5 <-> 22.03
# 4.9 <-> 6.24
# 12.0 <-> 13.26
# 31.3 <-> 26.02
# 4.5 <-> 5.21
# 11.5 <-> 11.84
# 5.5 <-> 6.88
# 19.0 <-> 13.15
# 27.07 <-> 28.43
# 6.5 <-> 7.71
# 28.27 <-> 26.12
# 3.7 <-> 5.21
# 6.5 <-> 9.15
# 8.9 <-> 9.9
# 5.5 <-> 6.28
# 12.5 <-> 15.78
# 4.1 <-> 5.21
# 4.9 <-> 5.21
# 26.1 <-> 29.45
# 13.7 <-> 13.69
# 29.07 <-> 27.63
# 7.3 <-> 9.22
# 16.1 <-> 16.93
# 11.0 <-> 10.41
# 5.3 <-> 6.28
# 6.9 <-> 9.06
# 14.5 <-> 15.78
# 6.5 <-> 5.6
# 9.0 <-> 7.96
# 9.0 <-> 10.01
# 9.7 <-> 9.79
# 14.9 <-> 12.13
# 9.0 <-> 8.33
# 12.0 <-> 13.57
# 6.1 <-> 6.28
# 10.5 <-> 9.89
# 4.1 <-> 5.21
# 7.7 <-> 9.14
# 9.7 <-> 12.13
# 13.7 <-> 12.19
# 12.5 <-> 8.18
# 6.5 <-> 7.55
# 4.9 <-> 6.84
# 35.3 <-> 26.52
# 6.5 <-> 6.91
# 18.5 <-> 24.2
# 6.0 <-> 8.01
# 6.5 <-> 5.21
# 10.5 <-> 6.25
# 13.7 <-> 13.58
# 7.7 <-> 8.67
# 10.5 <-> 9.16
# 21.5 <-> 25.04
# 7.0 <-> 8.08
# 8.1 <-> 10.64
# 6.0 <-> 6.28
# 10.5 <-> 10.41
# 33.83 <-> 30.44
# 7.7 <-> 7.44
# 3.7 <-> 5.21
# 14.0 <-> 11.86
# 16.5 <-> 17.05
# 4.1 <-> 6.28
# 7.0 <-> 6.65
# 4.9 <-> 6.19
# 11.0 <-> 15.02
# 6.0 <-> 5.69
# 16.1 <-> 17.78
# 7.5 <-> 9.35
# 18.1 <-> 17.62
# 10.1 <-> 8.66
# 7.3 <-> 7.16
# 10.1 <-> 12.13
# 11.0 <-> 11.97
# 8.5 <-> 8.67
# 9.7 <-> 9.83
# 10.1 <-> 9.83
# 10.5 <-> 5.21
# 15.3 <-> 7.71
# 11.5 <-> 13.31
# 16.0 <-> 17.76
# 5.3 <-> 7.71
# 4.9 <-> 5.21
# 4.1 <-> 6.19
# 8.5 <-> 10.57
# 27.3 <-> 17.89
# 18.0 <-> 19.72
# 13.0 <-> 13.53
# 8.9 <-> 9.77
# 9.7 <-> 10.36
# 7.7 <-> 9.16
# 7.3 <-> 6.28
# 20.1 <-> 15.18
# 14.5 <-> 14.75
# 6.5 <-> 8.58
# 5.5 <-> 6.28
# 6.0 <-> 6.28
# 9.3 <-> 10.88
# 7.7 <-> 8.66
# 13.7 <-> 12.13
# 4.9 <-> 6.28
# 7.7 <-> 6.9
# 4.5 <-> 5.21
# 6.5 <-> 8.67
# 9.0 <-> 9.15
# 13.7 <-> 13.58
# 20.5 <-> 15.18
# 8.5 <-> 12.13
# 29.0 <-> 30.44
# 7.7 <-> 7.71
# 11.3 <-> 6.28
# 10.0 <-> 5.73
# 5.5 <-> 5.69
# 36.54 <-> 32.96
# 8.5 <-> 8.54
# 10.5 <-> 9.8
# 7.0 <-> 6.88
# 12.5 <-> 13.58
# 11.0 <-> 11.84
# 6.1 <-> 5.21
# 6.5 <-> 5.21
# 6.0 <-> 5.69
# 10.1 <-> 10.89
# 3.7 <-> 5.21
# 4.0 <-> 5.21
# 7.5 <-> 8.01
# 12.0 <-> 11.83
# 6.0 <-> 5.26
# 4.9 <-> 5.26
# 6.5 <-> 6.82
# 5.7 <-> 5.21
# 6.5 <-> 8.66
# 13.5 <-> 10.51
# 4.1 <-> 5.21
# 4.5 <-> 5.21
# 11.5 <-> 13.49
# 9.5 <-> 10.42
# 6.0 <-> 6.28
# 4.5 <-> 6.24
# 11.5 <-> 11.84
# 8.1 <-> 9.66
# 5.0 <-> 5.21
# 18.0 <-> 10.13
# 4.5 <-> 5.21
# 7.7 <-> 7.71
# 6.1 <-> 6.9
# 17.7 <-> 26.12
# 7.7 <-> 7.71
# 4.0 <-> 5.21
# 11.5 <-> 10.42
# 6.5 <-> 7.73
# 6.9 <-> 6.28
# 11.3 <-> 8.12
# 7.3 <-> 7.71
# 6.9 <-> 6.9
# 13.7 <-> 12.13
# 8.5 <-> 9.15
# 20.1 <-> 28.17
# 5.7 <-> 6.28
# 12.1 <-> 9.57
# 7.5 <-> 9.15
# 6.1 <-> 6.28
# 10.5 <-> 10.88
# 8.0 <-> 6.82
# 20.5 <-> 17.05
# 6.1 <-> 6.28
# 8.5 <-> 8.66
# 7.5 <-> 6.28
# 14.5 <-> 13.26
# 5.0 <-> 5.21
# 5.5 <-> 5.72
# 13.3 <-> 9.89
# 7.3 <-> 7.71
# 10.1 <-> 8.6
# 5.7 <-> 7.71
# 20.1 <-> 10.98
# 6.0 <-> 6.28
# 8.0 <-> 6.28
# 12.0 <-> 10.51
# 4.5 <-> 5.21
# 11.7 <-> 12.13
# 8.5 <-> 8.67
# 17.5 <-> 17.72
# 4.9 <-> 5.21
# 11.5 <-> 10.41
# 17.5 <-> 10.46
# 6.0 <-> 5.21
# 10.0 <-> 13.26
# 4.9 <-> 5.22
# 10.0 <-> 12.12
# 4.5 <-> 5.73
# 7.3 <-> 8.66
# 14.5 <-> 17.89
# 6.1 <-> 7.71
# 10.5 <-> 10.87
# 6.9 <-> 8.58
# 7.7 <-> 6.28
# 7.3 <-> 9.13
# 21.5 <-> 25.69
# 5.3 <-> 6.28
# 12.0 <-> 13.49
# 5.3 <-> 6.23
# 5.5 <-> 5.69
# 14.9 <-> 13.5
# 7.0 <-> 8.01
# 3.5 <-> 5.21
# 16.0 <-> 18.38
# 5.0 <-> 5.21
# 9.0 <-> 9.15
# 4.5 <-> 5.21
# 14.9 <-> 13.58
# 5.7 <-> 6.28
# 6.1 <-> 6.85
# 5.3 <-> 6.28
# 8.1 <-> 10.87
# 5.3 <-> 5.21
# 6.0 <-> 6.28
# 7.1 <-> 6.28
# 7.3 <-> 7.71
# 5.7 <-> 5.26
# 4.5 <-> 5.28
# 33.870000000000005 <-> 29.58
# 6.5 <-> 7.72
# 8.5 <-> 8.59
# 10.5 <-> 13.56
# 17.0 <-> 13.42
# 15.7 <-> 13.29
# 7.0 <-> 7.96
# 6.1 <-> 7.1
# 4.5 <-> 6.19
# 10.0 <-> 8.66
# 12.1 <-> 12.17
# 5.3 <-> 6.28
# 8.9 <-> 9.77
# 14.5 <-> 12.23
# 11.5 <-> 9.15
# 10.5 <-> 9.92
# 7.5 <-> 6.28
# 4.9 <-> 6.82
# 5.5 <-> 6.28
# 6.5 <-> 6.28
# 15.0 <-> 11.85
# 4.5 <-> 6.28
# 8.1 <-> 6.28
# 6.9 <-> 6.9
# 10.0 <-> 5.21
# 12.1 <-> 13.58
# 4.9 <-> 9.79
# 10.1 <-> 13.49
# 5.7 <-> 5.28
# 24.83 <-> 25.56
# 5.7 <-> 6.28
# 10.0 <-> 10.42
# 15.7 <-> 13.58
# 9.0 <-> 10.41
# 6.5 <-> 5.21
# 5.3 <-> 6.28
# 14.0 <-> 17.4
# 12.0 <-> 11.72
# 8.0 <-> 8.08
# 8.5 <-> 7.71
# 4.9 <-> 6.19
# 4.9 <-> 5.21
# 3.5 <-> 5.21
# 16.0 <-> 13.3
# 10.0 <-> 11.84
# 5.7 <-> 6.9
# 5.5 <-> 8.41
# 11.3 <-> 13.56
# 5.7 <-> 9.62
# 8.5 <-> 9.47
# 23.0 <-> 17.3
# 7.3 <-> 6.9
# 16.9 <-> 17.89
# 9.0 <-> 10.42
# 8.9 <-> 8.66
# 12.9 <-> 13.74
# 8.0 <-> 6.28
# 30.0 <-> 32.96
# 6.1 <-> 5.66
# 8.9 <-> 10.87
# 7.7 <-> 6.9
# 5.7 <-> 5.21
# 3.3 <-> 5.21
# 9.3 <-> 7.71
# 11.0 <-> 11.89
# 11.0 <-> 10.19
# 4.9 <-> 6.5
# 6.5 <-> 10.21
# 8.1 <-> 9.89
# 3.0 <-> 6.46
# 13.7 <-> 10.89
# 7.5 <-> 5.24
# 12.0 <-> 13.26
# 8.0 <-> 7.99
# 7.7 <-> 6.9
# 8.0 <-> 8.18
# 5.7 <-> 5.95
# 6.5 <-> 5.24
# 4.9 <-> 6.28
# 4.5 <-> 5.66
# 6.9 <-> 7.1
# 10.5 <-> 10.41
# 30.27 <-> 23.48
# 19.0 <-> 10.87
# 6.5 <-> 6.28
# 4.1 <-> 5.21
# 8.5 <-> 10.19
# 9.3 <-> 9.05
# 7.0 <-> 8.01
# 4.9 <-> 5.21
# 8.5 <-> 7.96
# 12.1 <-> 12.08
# 4.9 <-> 6.19
# 13.7 <-> 10.87
# 6.5 <-> 10.35
# 6.1 <-> 6.89
# 3.7 <-> 5.21
# 5.5 <-> 6.24
# 6.5 <-> 7.71
# 8.5 <-> 8.1
# 5.5 <-> 5.72
# 8.0 <-> 6.28
# 19.0 <-> 19.72
# 9.0 <-> 13.15
# 5.5 <-> 6.28
# 15.3 <-> 16.93
# 3.7 <-> 5.21
# 5.7 <-> 6.28
# 16.0 <-> 10.19
# 5.7 <-> 6.28
# 31.7 <-> 29.55
# 6.0 <-> 6.28
# 5.7 <-> 6.9
# 4.1 <-> 5.21
# 7.0 <-> 6.28
# 5.0 <-> 6.08
# 8.5 <-> 7.07
# 5.3 <-> 6.9
# 15.3 <-> 5.21
# 8.9 <-> 9.65
# 8.5 <-> 6.9
# 36.0 <-> 25.58
# 19.8 <-> 21.54
# 13.5 <-> 13.26
# 3.7 <-> 5.21
# 5.0 <-> 5.22
# 6.5 <-> 6.26
# 4.5 <-> 5.21
# 29.8 <-> 29.45
# 7.7 <-> 9.77
# 11.0 <-> 10.42
# 36.0 <-> 26.12
# 10.9 <-> 13.58
# 10.5 <-> 8.93
# 15.3 <-> 13.65
# 6.7 <-> 6.28
# 6.5 <-> 10.33
# 11.0 <-> 11.72
# 8.0 <-> 8.01
# 5.7 <-> 6.19
# 17.3 <-> 17.6
# 6.9 <-> 5.23
# 6.5 <-> 6.67
# 4.9 <-> 5.25
# 13.3 <-> 13.52
# 10.9 <-> 10.34
# 17.0 <-> 12.12
# 7.0 <-> 8.01
# 8.5 <-> 9.22
# 4.5 <-> 6.9
# 16.1 <-> 16.89
# 12.0 <-> 10.42
# 5.7 <-> 6.28
# 15.0 <-> 17.58
# 11.3 <-> 12.23
# 6.9 <-> 5.21
# 16.9 <-> 10.36
# 8.9 <-> 7.71
# 8.1 <-> 10.65
# 8.5 <-> 8.66
# 14.1 <-> 13.58
# 5.5 <-> 8.01
# 4.1 <-> 5.21
# 12.5 <-> 15.02
# 4.5 <-> 6.19
# 12.9 <-> 12.2
# 18.1 <-> 17.85
# 4.1 <-> 5.3
# 5.3 <-> 6.84
# 6.5 <-> 6.9
# 7.5 <-> 5.3
# 7.0 <-> 9.15
# 8.5 <-> 9.15
# 9.7 <-> 11.46
# 10.0 <-> 13.32
# 36.33 <-> 30.44
# 7.3 <-> 8.67
# 9.3 <-> 12.13
# 8.5 <-> 7.71
# 10.1 <-> 10.36
# 10.0 <-> 13.31
# 11.7 <-> 8.66
# 8.9 <-> 7.71
# 6.9 <-> 7.71
# 8.9 <-> 10.87
# 9.5 <-> 9.35
# 5.7 <-> 8.66
# 11.5 <-> 10.41
# 23.5 <-> 19.72
# 4.5 <-> 5.69
# 4.5 <-> 5.21
# 4.9 <-> 5.21
# 18.1 <-> 16.46
# 22.0 <-> 13.58
# 16.9 <-> 23.16
# 6.5 <-> 7.57
# 8.0 <-> 9.14
# 5.7 <-> 5.73
# 12.5 <-> 9.06
# 5.3 <-> 6.28
# 5.3 <-> 6.28
# 12.0 <-> 10.78
# 5.7 <-> 6.28
# 4.1 <-> 5.21
# 6.5 <-> 6.28
# 4.5 <-> 5.66
# 5.3 <-> 6.24
# 6.9 <-> 6.9
# 6.5 <-> 8.01
# 24.5 <-> 32.73
# 13.3 <-> 13.6
# 9.0 <-> 10.46
# 6.0 <-> 5.24
# 8.9 <-> 6.28
# 6.5 <-> 7.71
# 4.9 <-> 5.21
# 4.1 <-> 5.21
# 6.5 <-> 8.93
# 16.1 <-> 17.62
# 8.5 <-> 7.16
# 7.5 <-> 7.73
# 4.5 <-> 5.21
# 6.5 <-> 5.22
# 9.7 <-> 6.9
# 13.3 <-> 15.23
# 7.5 <-> 8.18
# 28.5 <-> 19.52
# 3.7 <-> 5.21
# 5.7 <-> 6.93
# 10.5 <-> 16.39
# 6.1 <-> 8.66
# 4.1 <-> 5.22
# 8.0 <-> 10.41
# 4.0 <-> 6.28
# 7.3 <-> 9.22
# 6.9 <-> 6.89
# 4.9 <-> 6.26
# 8.0 <-> 5.21
# 3.7 <-> 5.21
# 10.5 <-> 10.87
# 11.5 <-> 7.87
# 11.7 <-> 6.84
# 12.9 <-> 14.53
# 7.7 <-> 9.13
# 5.7 <-> 7.16
# 4.0 <-> 5.21
# 12.1 <-> 9.83
# 10.0 <-> 10.41
# 30.1 <-> 26.12
# 5.0 <-> 5.21
# 5.3 <-> 6.89
# 6.1 <-> 8.66
# 35.33 <-> 32.96
# 19.3 <-> 18.59
# 4.1 <-> 5.66
# 10.5 <-> 10.41
# 4.0 <-> 5.21
# 4.9 <-> 7.57
# 5.5 <-> 5.69
# 31.8 <-> 22.66
# ...
# 10.5 <-> 8.1
# 6.0 <-> 6.29
# 6.1 <-> 6.91
# 5.7 <-> 6.23
# 13.0 <-> 10.87
# 5.3 <-> 6.19
# 13.3 <-> 14.73
# 9.5 <-> 8.12
# 10.5 <-> 13.58
# 20.5 <-> 17.83
# 8.5 <-> 9.15
# 4.1 <-> 5.69
# 7.0 <-> 9.14
# 8.9 <-> 6.19
# 6.7 <-> 5.21
# 8.5 <-> 8.59
# 6.9 <-> 8.67
# 6.1 <-> 6.28
# 6.5 <-> 6.29
# 10.0 <-> 9.15
# 2.5 <-> 5.28
# 10.5 <-> 14.25
# 5.3 <-> 6.82
# 5.4 <-> 6.28
# 4.5 <-> 6.28
# 5.5 <-> 5.21
# 9.7 <-> 9.8
# 9.0 <-> 10.41
# 27.3 <-> 26.12
# 4.5 <-> 5.21
# 19.5 <-> 18.0
# 7.7 <-> 6.9
# 7.7 <-> 5.3
# 9.0 <-> 10.35
# 7.7 <-> 8.66
# 11.0 <-> 10.08
# 7.5 <-> 7.71
# 7.5 <-> 8.01
# 7.1 <-> 6.9
# 10.1 <-> 8.66
# 10.9 <-> 10.02
# 7.0 <-> 6.28
# 27.7 <-> 21.58
# 7.5 <-> 6.28
# 8.5 <-> 8.66
# 5.5 <-> 5.21
# 21.5 <-> 19.83
# 13.5 <-> 13.3
# 4.0 <-> 5.21
# 16.5 <-> 16.48
# 13.3 <-> 15.18
# 11.0 <-> 9.23
# 6.9 <-> 7.73
# 7.3 <-> 8.66
# 6.1 <-> 7.71
# 16.1 <-> 16.88
# 6.0 <-> 6.28
# 8.5 <-> 8.66
# 13.3 <-> 13.58
# 4.9 <-> 5.21
# 4.0 <-> 5.21
# 12.5 <-> 9.47
# 18.0 <-> 11.81
# 4.9 <-> 5.21
# 8.5 <-> 8.66
# 7.3 <-> 6.45
# 6.1 <-> 6.89
# 6.1 <-> 6.29
# 8.0 <-> 10.41
# 8.9 <-> 10.87
# 14.1 <-> 12.13
# 6.5 <-> 9.66
# 9.0 <-> 11.85
# 12.5 <-> 10.88
# 27.5 <-> 32.88
# 5.3 <-> 6.08
# 6.9 <-> 6.28
# 6.5 <-> 8.08
# 3.7 <-> 5.21
# 3.7 <-> 5.24
# 14.0 <-> 11.97
# 6.0 <-> 8.93
# 5.0 <-> 5.21
# 18.5 <-> 20.06
# 6.1 <-> 6.28
# 9.5 <-> 11.89
# 8.9 <-> 9.05
# 8.0 <-> 6.29
# 10.1 <-> 10.96
# 11.5 <-> 11.86
# 7.0 <-> 8.21
# 18.5 <-> 13.42
# 4.5 <-> 5.21
# 8.5 <-> 12.53
# 9.3 <-> 13.58
# 7.0 <-> 8.34
# 8.1 <-> 7.71
# 12.5 <-> 13.31
# 12.1 <-> 9.79
# 5.0 <-> 6.28
# 8.5 <-> 6.93
# 4.5 <-> 5.21
# 9.0 <-> 11.8
# 7.5 <-> 8.01
# 6.1 <-> 6.89
# 4.9 <-> 6.28
# 13.5 <-> 15.01
# 14.0 <-> 12.0
# 6.5 <-> 6.9
# 3.7 <-> 6.23
# 5.3 <-> 6.82
# 6.1 <-> 6.9
# 8.0 <-> 7.99
# 4.9 <-> 5.21
# 9.7 <-> 9.78
# 8.5 <-> 7.71
# 18.0 <-> 12.13
# 11.3 <-> 10.88
# 24.0 <-> 17.68
# 10.9 <-> 10.93
# 12.1 <-> 12.19
# 5.0 <-> 5.21
# 9.5 <-> 10.51
# 10.5 <-> 12.58
# 4.9 <-> 6.28
# 13.5 <-> 10.32
# 12.5 <-> 10.87
# 7.7 <-> 9.14
# 8.0 <-> 7.71
# 23.0 <-> 16.61
# 12.5 <-> 12.11
# 21.5 <-> 19.63
# 13.5 <-> 13.65
# 8.9 <-> 10.64
# 5.0 <-> 5.21
# 5.7 <-> 5.21
# 12.1 <-> 9.83
# 8.0 <-> 6.9
# 6.5 <-> 6.9
# 7.5 <-> 8.93
# 10.9 <-> 10.02
# 5.3 <-> 6.28
# 12.5 <-> 14.56
# 10.0 <-> 10.53
# 6.5 <-> 7.55
# 4.5 <-> 5.25
# 4.9 <-> 6.9
# 3.5 <-> 5.21
# 7.0 <-> 5.21
# 26.1 <-> 17.75
# 9.7 <-> 12.2
# 6.5 <-> 6.91
# 6.0 <-> 6.28
# 33.33 <-> 32.96
# 34.1 <-> 24.31
# 35.33 <-> 28.85
# 7.0 <-> 5.21
# 25.5 <-> 26.36
# 11.0 <-> 9.73
# 8.1 <-> 9.57
# 16.1 <-> 15.23
# 12.9 <-> 9.81
# 10.0 <-> 9.14
# 10.5 <-> 9.22
# 5.0 <-> 5.98
# 6.5 <-> 7.55
# 30.0 <-> 6.45
# 14.0 <-> 9.06
# 6.9 <-> 8.66
# 4.5 <-> 5.72
# 7.3 <-> 7.73
# 6.9 <-> 5.28
# 10.9 <-> 9.78
# 13.0 <-> 13.26
# 6.9 <-> 7.1
# 25.5 <-> 27.73
# 22.1 <-> 26.12
# 9.3 <-> 6.9
# 6.5 <-> 6.28
# 6.5 <-> 7.71
# 7.7 <-> 9.66
# 27.5 <-> 25.56
# 5.0 <-> 5.21
# 5.7 <-> 5.21
# 8.5 <-> 8.01
# 8.1 <-> 6.89
# 5.3 <-> 6.28
# 4.1 <-> 5.21
# 10.5 <-> 11.86
# 8.1 <-> 8.66
# 12.5 <-> 11.97
# 5.3 <-> 6.28
# 14.5 <-> 17.6
# 30.0 <-> 30.61
# 12.9 <-> 5.21
# 8.1 <-> 7.71
# 9.3 <-> 6.9
# 14.0 <-> 13.3
# 6.2 <-> 7.71
# 8.5 <-> 9.15
# 13.7 <-> 9.05
# 8.0 <-> 8.08
# 8.5 <-> 9.8
# 3.7 <-> 5.21
# 23.0 <-> 25.56
# 7.7 <-> 9.23
# 7.3 <-> 7.71
# 11.7 <-> 6.91
# 19.0 <-> 16.93
# 6.9 <-> 6.82
# 2.5 <-> 5.25
# 10.5 <-> 10.35
# 4.5 <-> 5.73
# 5.5 <-> 5.21
# 17.5 <-> 19.45
# 15.7 <-> 12.2
# 11.5 <-> 10.44
# 4.9 <-> 5.21
# 9.7 <-> 9.78
# 3.0 <-> 5.21
# 6.5 <-> 6.9
# 4.9 <-> 5.21
# 6.5 <-> 5.26
# 13.5 <-> 13.26
# 29.0 <-> 32.73
# 6.1 <-> 8.66
# 4.5 <-> 6.24
# 8.9 <-> 7.55
# 5.3 <-> 6.89
# 22.9 <-> 19.44
# 15.5 <-> 7.99
# 6.1 <-> 6.28
# 17.7 <-> 14.73
# 6.5 <-> 7.1
# 26.83 <-> 19.27
# 4.5 <-> 5.21
# 8.0 <-> 10.42
# 8.5 <-> 7.73
# 6.9 <-> 6.91
# 4.9 <-> 6.28
# 5.7 <-> 6.88
# 14.5 <-> 17.79
# 28.9 <-> 26.12
# 12.7 <-> 10.89
# 5.3 <-> 6.28
# 9.3 <-> 9.83
# 7.5 <-> 5.21
# 8.5 <-> 10.87
# 10.5 <-> 10.65
# 18.5 <-> 17.59
# 9.0 <-> 10.41
# 8.5 <-> 6.9
# 4.1 <-> 5.24
# 6.0 <-> 8.01
# 10.0 <-> 9.15
# 7.7 <-> 8.66
# 20.0 <-> 6.25
# 2.5 <-> 5.25
# 7.3 <-> 7.68
# 5.3 <-> 6.19
# 9.3 <-> 9.79
# 10.5 <-> 10.52
# 4.5 <-> 5.28
# 7.0 <-> 5.24
# 7.7 <-> 16.88
# 7.7 <-> 7.68
# 6.1 <-> 6.28
# 29.0 <-> 30.3
# 6.5 <-> 5.26
# 5.7 <-> 6.08
# 8.0 <-> 5.21
# 2.5 <-> 8.66
# 7.0 <-> 5.21
# 5.3 <-> 5.24
# 4.9 <-> 6.28
# 37.33 <-> 26.13
# 6.0 <-> 6.28
# 11.0 <-> 10.41
# 3.3 <-> 5.21
# 8.1 <-> 8.03
# 7.5 <-> 7.87
# 5.0 <-> 5.21
# 12.9 <-> 13.6
# 14.1 <-> 13.58
# 11.0 <-> 13.31
# 10.5 <-> 10.89
# 8.9 <-> 8.66
# 6.2 <-> 6.88
# 7.7 <-> 9.13
# 12.1 <-> 12.13
# 3.0 <-> 5.21
# 4.9 <-> 5.21
# 3.7 <-> 5.21
# 13.5 <-> 10.42
# 9.3 <-> 7.68
# 17.0 <-> 16.71
# 3.0 <-> 5.21
# 13.5 <-> 15.02
# 6.5 <-> 7.71
# 17.5 <-> 20.53
# 5.5 <-> 8.08
# 11.0 <-> 6.28
# 13.5 <-> 11.72
# 9.5 <-> 8.66
# 6.1 <-> 6.9
# 30.5 <-> 30.44
# 6.5 <-> 5.21
# 6.5 <-> 6.28
# 5.3 <-> 6.28
# 4.9 <-> 7.71
# 6.5 <-> 6.9
# 12.5 <-> 6.28
# 8.5 <-> 10.36
# 7.7 <-> 10.65
# 6.5 <-> 10.51
# 9.7 <-> 8.6
# 6.1 <-> 8.66
# 15.3 <-> 16.38
# 12.0 <-> 6.88
# 7.7 <-> 8.66
# 12.9 <-> 10.88
# 16.5 <-> 17.05
# 6.1 <-> 6.43
# 5.7 <-> 6.82
# 3.3 <-> 5.21
# 6.0 <-> 6.28
# 6.0 <-> 6.28
# 11.0 <-> 8.42
# 4.1 <-> 5.21
# 14.5 <-> 15.02
# 12.5 <-> 12.56
# 7.5 <-> 8.34
# 13.5 <-> 13.31
# 8.1 <-> 10.64
# 13.3 <-> 10.65
# 6.1 <-> 6.28
# 3.7 <-> 5.21
# 8.5 <-> 9.57
# 13.3 <-> 16.99
# 4.0 <-> 5.21
# 4.0 <-> 5.21
# 13.0 <-> 13.26
# 8.0 <-> 7.96
# 7.7 <-> 6.5
# 6.1 <-> 6.84
# 9.5 <-> 11.84
# 16.0 <-> 20.58
# 18.5 <-> 16.88
# 3.7 <-> 5.21
# 11.5 <-> 10.51
# 6.5 <-> 7.07
# 27.7 <-> 26.12
# 8.9 <-> 6.9
# 7.5 <-> 9.46
# 4.5 <-> 5.25
# 15.1 <-> 14.74
# 9.0 <-> 8.41
# 6.5 <-> 8.66
# 6.1 <-> 6.28
# 3.5 <-> 5.21
# 5.0 <-> 6.28
# 17.5 <-> 7.77
# 5.7 <-> 6.93
# 9.0 <-> 9.02
# 9.0 <-> 7.77
# 4.0 <-> 5.24
# 10.0 <-> 10.87
# 5.7 <-> 5.28
# 32.33 <-> 30.44
# 4.5 <-> 5.24
# 18.0 <-> 16.88
# 15.0 <-> 12.23
# 10.5 <-> 6.82
# 11.7 <-> 6.93
# 8.1 <-> 9.57
# 10.0 <-> 12.56
# 10.0 <-> 9.17
# 17.5 <-> 15.02
# 4.9 <-> 6.88
# 7.5 <-> 9.15
# 9.7 <-> 7.85
# 9.5 <-> 5.25
# 6.5 <-> 6.28
# 11.5 <-> 10.08
# 7.5 <-> 10.42
# 10.6 <-> 13.58
# 11.7 <-> 10.36
# 9.7 <-> 7.71
# 9.4 <-> 8.66
# 10.5 <-> 10.41
# 11.3 <-> 11.72
# 8.0 <-> 10.41
# 8.9 <-> 7.71
# 20.0 <-> 22.17
# 6.9 <-> 5.21
# 5.5 <-> 5.66
# 6.5 <-> 6.65
# 4.5 <-> 6.28
# 14.5 <-> 10.87
# 8.5 <-> 9.9
# 8.9 <-> 9.13
# 6.5 <-> 6.9
# 7.0 <-> 6.67
# 14.9 <-> 14.65
# 9.5 <-> 9.15
# 9.3 <-> 10.88
# 13.7 <-> 16.99
# 4.1 <-> 5.21
# 15.0 <-> 12.08
# 20.0 <-> 25.58
# 7.7 <-> 7.76
# 15.5 <-> 13.26
# 9.7 <-> 10.87
# 6.1 <-> 7.71
# 10.1 <-> 7.71
# 10.3 <-> 8.66
# 14.1 <-> 9.57
# 8.0 <-> 11.84
# 11.0 <-> 9.15
# 8.5 <-> 8.01
# 4.5 <-> 5.21
# 10.0 <-> 10.51
# 14.1 <-> 15.29
# 17.0 <-> 13.34
# 10.5 <-> 9.47
# 9.0 <-> 9.23
# 10.5 <-> 12.13
# 9.0 <-> 6.28
# 10.1 <-> 8.67
# 13.0 <-> 11.87
# 8.5 <-> 8.54
# 12.0 <-> 10.44
# 8.1 <-> 6.9
# 4.5 <-> 5.21
# 7.7 <-> 7.71
# 9.0 <-> 9.15
# 10.9 <-> 7.71
# 4.5 <-> 5.21
# 6.9 <-> 7.71
# 4.5 <-> 6.28
# 30.27 <-> 27.1
# 9.5 <-> 11.96
# 4.5 <-> 5.21
# 11.0 <-> 10.51
# 6.5 <-> 6.91
# 6.5 <-> 6.28
# 6.0 <-> 5.21
# 15.5 <-> 18.28
# 9.0 <-> 11.46
# 5.0 <-> 5.73
# 4.5 <-> 5.21
# 9.0 <-> 12.93
# 3.3 <-> 5.21
# 24.5 <-> 23.33
# 6.0 <-> 6.28
# 5.7 <-> 5.22
# 8.9 <-> 9.65
# 8.0 <-> 8.98
# 9.0 <-> 10.41
# 10.1 <-> 12.13
# 15.0 <-> 15.16
# 8.5 <-> 8.93
# 6.9 <-> 8.59
# 5.5 <-> 5.6
# 6.5 <-> 6.89
# 5.3 <-> 5.21
# 9.5 <-> 9.6
# 6.5 <-> 13.53
# 3.3 <-> 9.57
# 16.5 <-> 18.28
# 11.7 <-> 14.56
# 4.9 <-> 5.21
# 5.7 <-> 6.28
# 4.5 <-> 6.89
# 4.5 <-> 5.69
# 6.9 <-> 6.28
# 8.5 <-> 9.18
# 6.0 <-> 6.28
# 7.0 <-> 5.3
# 8.5 <-> 10.41
# 6.9 <-> 8.66
# 5.3 <-> 6.91
# 12.5 <-> 7.99
# 4.1 <-> 6.26
# 8.5 <-> 10.44
# 10.0 <-> 5.21
# 12.0 <-> 12.94
# 3.5 <-> 5.21
# 6.1 <-> 6.28
# 11.0 <-> 10.43
# 11.0 <-> 9.14
# 8.5 <-> 7.71
# 16.5 <-> 18.38
# 6.9 <-> 7.71
# 14.1 <-> 14.73
# 6.5 <-> 5.25
# 4.5 <-> 5.28
# 10.0 <-> 10.52
# 5.7 <-> 6.85
# 6.5 <-> 5.26
# 7.0 <-> 9.21
# 14.0 <-> 13.26
# 35.07 <-> 29.56
# 6.5 <-> 6.28
# 13.0 <-> 8.67
# 8.9 <-> 9.06
# 6.0 <-> 5.21
# 10.9 <-> 9.46
# 5.0 <-> 6.28
# 10.5 <-> 6.71
# 3.3 <-> 5.21
# 11.7 <-> 14.73
# 5.0 <-> 6.28
# 8.1 <-> 7.73
# 6.9 <-> 7.71
# 11.7 <-> 12.13
# 19.5 <-> 17.05
# 33.47 <-> 29.23
# 8.5 <-> 8.66
# 4.5 <-> 6.5
# 7.3 <-> 6.93
# 12.5 <-> 9.14
# 6.5 <-> 8.12
# 4.5 <-> 5.21
# 31.37 <-> 32.94
# 8.5 <-> 6.28
# 18.1 <-> 10.64
# 37.33 <-> 30.44
# 6.1 <-> 5.21
# 8.5 <-> 9.8
# 6.0 <-> 6.28
# 5.7 <-> 6.28
# 17.5 <-> 5.22
# 8.1 <-> 6.28
# 6.5 <-> 6.28
# 9.0 <-> 5.25
# 11.3 <-> 9.57
# 9.5 <-> 10.51
# 6.0 <-> 6.28
# 10.1 <-> 7.77
# 3.7 <-> 5.21
# 7.3 <-> 8.66
# 4.5 <-> 6.82
# 6.9 <-> 6.93
# 8.0 <-> 7.57
# 36.04 <-> 25.58
# 6.5 <-> 5.21
# 4.1 <-> 5.21
# 6.1 <-> 6.9
# 6.9 <-> 7.76
# 7.7 <-> 8.53
# 4.9 <-> 5.21
# 16.0 <-> 20.3
# 6.9 <-> 8.03
# 8.1 <-> 8.66
# 12.9 <-> 13.57
# 16.5 <-> 15.14
# 6.9 <-> 9.05
# 6.0 <-> 6.28
# 6.9 <-> 6.88
# 7.0 <-> 8.01
# 13.3 <-> 13.59
# 14.9 <-> 16.38
# 9.5 <-> 6.23
# 16.9 <-> 19.48
# 6.1 <-> 6.9
# 6.9 <-> 9.77
# 11.5 <-> 11.85
# 5.0 <-> 5.21
# 9.3 <-> 7.44
# 6.9 <-> 5.21
# 6.0 <-> 6.28
# 6.1 <-> 6.9
# 18.0 <-> 18.33
# 8.5 <-> 9.14
# 9.0 <-> 11.81
# 6.5 <-> 6.23
# 10.0 <-> 9.73
# 12.5 <-> 7.16
# 4.1 <-> 5.28
# 25.07 <-> 22.38
# 6.1 <-> 7.16
# 5.3 <-> 5.25
# 4.9 <-> 6.19
# 8.0 <-> 8.77
# 8.0 <-> 9.15
# 8.9 <-> 5.21
# 5.3 <-> 6.9
# 7.5 <-> 9.15
# 8.0 <-> 8.01
# 8.9 <-> 6.28
# 5.7 <-> 7.07
# 14.0 <-> 15.7
# 6.5 <-> 6.93
# 4.5 <-> 5.66
# 9.3 <-> 5.21
# 8.1 <-> 9.06
# 5.7 <-> 6.9
# 3.7 <-> 9.57
# 15.7 <-> 17.62
# 9.5 <-> 6.28
# 12.5 <-> 13.31
# 4.9 <-> 6.19
# 3.7 <-> 5.21
# 10.9 <-> 12.13
# 6.5 <-> 9.78
# 7.3 <-> 6.91
# 4.5 <-> 5.21
# 8.5 <-> 10.44
# 18.0 <-> 17.59
# 14.9 <-> 12.17
# 14.5 <-> 9.77
# 4.9 <-> 7.71
# 8.0 <-> 7.77
# 6.1 <-> 6.28
# 9.3 <-> 9.78
# 5.0 <-> 6.28
# 5.5 <-> 5.95
# 7.5 <-> 10.43
# 7.0 <-> 9.15
# 4.9 <-> 5.21
# 4.9 <-> 6.28
# 5.3 <-> 7.71
# 8.1 <-> 9.83
# 8.5 <-> 10.51
# 5.5 <-> 6.28
# 6.9 <-> 6.43
# 6.0 <-> 6.28
# 7.7 <-> 7.71
# 7.0 <-> 9.15
# 14.5 <-> 16.45
# 9.7 <-> 12.05
# 9.0 <-> 6.28
# 8.9 <-> 6.93
# 3.0 <-> 5.25
# 8.0 <-> 6.28
# 6.5 <-> 8.66
# 7.0 <-> 7.99
# 7.5 <-> 8.01
# 8.5 <-> 10.87
# 5.3 <-> 6.28
# 17.5 <-> 11.72
# 7.5 <-> 6.28
# 18.0 <-> 17.89
# 8.0 <-> 8.18
# 6.1 <-> 6.9
# 11.5 <-> 8.01
# 7.3 <-> 7.71
# 6.0 <-> 6.28
# 22.0 <-> 32.88
# 7.0 <-> 6.28
# 3.7 <-> 5.21
# 8.9 <-> 9.05
# 8.0 <-> 8.08
# 7.0 <-> 6.19
# 4.9 <-> 6.28
# 4.5 <-> 5.21
# 7.5 <-> 5.6
# 26.2 <-> 26.21
# 4.0 <-> 5.21
# 4.0 <-> 5.21
# 5.7 <-> 6.29
# 9.5 <-> 10.42
# 9.0 <-> 11.84
# 6.0 <-> 5.21
# 6.0 <-> 5.28
# 5.3 <-> 6.9
# 15.7 <-> 17.67
# 11.5 <-> 10.11
# 10.0 <-> 11.86
# 15.0 <-> 10.52
# 16.0 <-> 15.14
# 6.9 <-> 7.71
# 4.9 <-> 6.28
# 6.9 <-> 7.71
# 8.1 <-> 7.71
# 20.5 <-> 16.7
# 27.0 <-> 30.3
# 8.1 <-> 6.9
# 8.0 <-> 8.37
# 17.0 <-> 17.05
# 8.5 <-> 7.77
# 4.1 <-> 5.21
# 13.3 <-> 11.46
# 8.5 <-> 8.77
# 10.9 <-> 10.88
# 9.5 <-> 5.95
# 18.1 <-> 14.73
# 13.7 <-> 16.93
# 8.0 <-> 10.19
# 16.0 <-> 6.28
# 8.1 <-> 6.9
# 4.0 <-> 5.21
# 10.1 <-> 12.58
# 6.1 <-> 5.69
# 8.9 <-> 7.71
# 6.0 <-> 6.28
# 3.7 <-> 5.21
# 7.0 <-> 6.28
# 9.7 <-> 9.46
# 9.7 <-> 9.79
# 4.0 <-> 5.21
# 5.3 <-> 6.08
# 8.5 <-> 8.66
# 8.5 <-> 7.77
# 9.5 <-> 9.77
# 26.0 <-> 30.44
# 10.0 <-> 12.56
# 10.0 <-> 10.41
# 4.9 <-> 6.19
# 15.3 <-> 10.87
# 7.7 <-> 10.8
# 8.5 <-> 9.13
# 4.9 <-> 10.87
# 8.5 <-> 6.89
# 6.1 <-> 5.21
# 9.5 <-> 12.83
# 8.9 <-> 7.71
# 4.9 <-> 5.21
# 10.9 <-> 8.66
# 17.0 <-> 18.32
# 12.9 <-> 14.25
# 22.5 <-> 7.68
# 15.7 <-> 17.75
# 24.9 <-> 21.65
# 4.1 <-> 5.25
# 8.0 <-> 9.15
# 3.3 <-> 5.21
# 14.0 <-> 10.51
# 5.5 <-> 5.21
# 9.3 <-> 9.57
# 15.5 <-> 13.58
# 7.0 <-> 8.34
# 8.5 <-> 6.91
# 4.1 <-> 5.95
# 15.7 <-> 16.43
# 9.3 <-> 6.9
# 4.5 <-> 5.21
# 4.5 <-> 5.21
# 10.9 <-> 12.19
# 10.5 <-> 13.31
# 10.5 <-> 10.89
# 6.5 <-> 8.86
# 4.5 <-> 6.28
# 10.9 <-> 9.78
# 5.7 <-> 6.88
# 8.5 <-> 9.14
# 16.2 <-> 17.62
# 6.0 <-> 6.28
# 5.7 <-> 6.9
# 8.0 <-> 6.9
# 31.33 <-> 30.3
# 6.9 <-> 7.44
# 14.0 <-> 15.14
# 10.5 <-> 10.42
# 5.3 <-> 6.28
# 9.5 <-> 8.58
# 6.1 <-> 6.9
# 4.5 <-> 6.19
# 5.3 <-> 5.22
# 34.0 <-> 30.51
# 14.0 <-> 10.41
# 14.5 <-> 15.01
# 5.0 <-> 6.28
# 15.0 <-> 15.02
# 19.0 <-> 13.58
# 12.1 <-> 15.16
# 4.5 <-> 5.21
# 22.1 <-> 26.12
# 15.7 <-> 13.74
# 6.0 <-> 6.28
# 11.7 <-> 9.47
# 6.5 <-> 6.28
# 8.5 <-> 8.66
# 5.3 <-> 6.89
# 5.7 <-> 7.71
# 5.3 <-> 6.28
# 10.1 <-> 6.89
# 7.5 <-> 8.01
# 4.9 <-> 5.22
# 11.7 <-> 14.55
# 11.5 <-> 9.15
# 5.0 <-> 5.21
# 7.7 <-> 8.59
# 8.5 <-> 9.15
# 15.5 <-> 13.31
# 9.7 <-> 10.88
# 8.0 <-> 7.87
# 10.5 <-> 10.01
# 22.0 <-> 17.04
# 23.0 <-> 22.17
# 5.5 <-> 5.21
# 4.0 <-> 5.21
# 8.5 <-> 6.28
# 7.3 <-> 6.82
# 11.0 <-> 10.43
# 4.5 <-> 6.24
# 7.5 <-> 5.21
# 4.0 <-> 5.21
# 7.0 <-> 6.28
# 4.5 <-> 6.23
# 5.0 <-> 5.21
# 4.9 <-> 6.28
# 6.1 <-> 6.9
# 4.9 <-> 6.29
# 5.3 <-> 6.9
# 7.7 <-> 8.66
# 7.7 <-> 7.71
# 5.7 <-> 5.69
# 6.9 <-> 6.28
# 4.1 <-> 5.21
# 3.0 <-> 5.21
# 4.9 <-> 5.21
# 4.1 <-> 5.21
# 7.0 <-> 9.15
# 8.9 <-> 9.89
# 8.0 <-> 10.33
# 10.5 <-> 10.53
# 5.7 <-> 7.73
# 14.5 <-> 10.42
# 6.5 <-> 6.28
# 4.2 <-> 5.21
# 28.5 <-> 29.45
# 10.5 <-> 10.87
# 7.7 <-> 7.1
# 9.7 <-> 8.66
# 14.5 <-> 14.04
# 7.0 <-> 8.01
# 5.5 <-> 6.19
# 7.3 <-> 7.71
# 7.3 <-> 7.71
# 23.5 <-> 21.6
# 4.9 <-> 5.73
# 4.1 <-> 5.21
# 16.1 <-> 10.51
# 12.5 <-> 8.6
# 6.5 <-> 7.16
# 13.3 <-> 9.62
# 5.3 <-> 6.84
# 6.9 <-> 7.71
# 7.0 <-> 8.41
# 4.1 <-> 5.21
# 10.0 <-> 9.15
# 18.5 <-> 13.81
# 4.5 <-> 5.21
# 7.7 <-> 8.67
# 5.5 <-> 6.88
# 29.3 <-> 26.12
# 16.5 <-> 17.61
# 6.0 <-> 5.73
# 11.4 <-> 9.57
# 4.5 <-> 5.21
# 6.0 <-> 5.73
# 5.5 <-> 5.21
# 6.5 <-> 8.01
# 4.5 <-> 5.21
# 8.5 <-> 9.64
# 8.5 <-> 7.73
# 3.7 <-> 5.21
# 5.5 <-> 6.28
# 8.1 <-> 9.23
# 3.7 <-> 6.23
# 4.9 <-> 5.24
# 6.1 <-> 6.26
# 27.5 <-> 30.31
# 6.1 <-> 6.19
# 3.3 <-> 5.21
# 14.5 <-> 10.87
# 14.9 <-> 13.56
# 12.0 <-> 13.74
# 9.5 <-> 6.28
# 11.5 <-> 10.41
# 8.1 <-> 9.81
# 5.7 <-> 8.66
# 8.9 <-> 9.22
# 4.1 <-> 5.21
# 14.9 <-> 13.58
# 25.5 <-> 25.58
# 16.5 <-> 17.26
# 6.5 <-> 6.28
# 6.5 <-> 6.28
# 6.5 <-> 5.21
# 27.0 <-> 21.91
# 8.5 <-> 6.28
# 10.0 <-> 10.51
# 12.5 <-> 12.13
# 14.5 <-> 17.62
# 16.0 <-> 10.08
# 36.5 <-> 29.57
# 3.3 <-> 5.21
# 5.7 <-> 6.43
# 9.0 <-> 11.85
# 9.5 <-> 11.97
# 5.3 <-> 5.72
# 12.0 <-> 7.96
# 2.9 <-> 5.21
# 5.3 <-> 5.21
# 6.5 <-> 7.71
# 3.3 <-> 7.72
# 7.3 <-> 9.06
# 4.5 <-> 6.9
# 5.0 <-> 6.28
# 8.1 <-> 9.13
# 6.5 <-> 6.91
# 9.7 <-> 8.66
# 15.7 <-> 17.19
# 17.0 <-> 13.31
# 15.0 <-> 12.09
# 6.1 <-> 8.67
# 10.1 <-> 8.58
# 29.5 <-> 30.3
# 5.3 <-> 10.88
# 11.0 <-> 10.42
# 8.1 <-> 5.73
# 18.5 <-> 15.51
# 6.5 <-> 5.21
# 14.1 <-> 15.29
# 15.3 <-> 13.58
# 3.7 <-> 6.82
# 8.1 <-> 9.78
# 8.0 <-> 9.72
# 6.9 <-> 8.66
# 9.3 <-> 12.13
# 6.9 <-> 6.29
# 8.5 <-> 10.41
# 13.3 <-> 14.74
# 11.3 <-> 12.17
# 13.7 <-> 12.13
# 6.5 <-> 6.28
# 9.5 <-> 9.65
# 6.5 <-> 6.9
# 5.0 <-> 5.23
# 7.0 <-> 6.28
# 7.0 <-> 5.21
# 4.9 <-> 6.28
# 5.5 <-> 6.28
# 9.7 <-> 9.13
# 5.7 <-> 6.28
# 19.3 <-> 22.65
# 34.27 <-> 29.06
# 7.3 <-> 6.9
# 15.5 <-> 13.59
# 15.0 <-> 11.81
# 21.3 <-> 22.58
# 31.83 <-> 25.85
# 7.7 <-> 6.28
# 6.1 <-> 6.93
# 15.0 <-> 19.83
# 7.0 <-> 10.51
# 3.7 <-> 5.21
# 7.0 <-> 7.77
# 5.0 <-> 5.21
# 30.0 <-> 30.12
# 10.5 <-> 6.28
# 4.9 <-> 6.26
# 5.0 <-> 5.21
# 9.0 <-> 9.78
# 5.5 <-> 6.28
# 6.5 <-> 6.9
# 4.0 <-> 5.21
# 8.9 <-> 8.59
# 2.9 <-> 5.21
# 7.5 <-> 10.41
# 6.0 <-> 5.21
# 17.3 <-> 22.51
# 10.5 <-> 10.51
# 6.0 <-> 5.21
# 8.5 <-> 7.71
# 4.1 <-> 5.21
# 8.0 <-> 6.28
# 9.3 <-> 12.13
# 13.0 <-> 10.41
# 22.5 <-> 10.02
# 9.3 <-> 6.28
# 7.7 <-> 9.81
# 11.7 <-> 14.74
# 3.7 <-> 6.19
# 5.5 <-> 7.85
# 16.9 <-> 16.99
# 12.5 <-> 12.19
# 14.9 <-> 12.19
# 6.1 <-> 6.29
# 4.5 <-> 5.21
# 7.7 <-> 5.21
# 16.0 <-> 13.57
# 36.83 <-> 32.96
# 5.7 <-> 6.28
# 24.9 <-> 29.45
# 11.0 <-> 11.96
# 7.3 <-> 6.9
# 8.1 <-> 9.06
# 12.0 <-> 10.52
# 10.9 <-> 10.98
# 7.7 <-> 6.28
# 14.5 <-> 15.18
# 5.5 <-> 5.95
# 7.7 <-> 9.78
# 7.3 <-> 7.1
# 6.5 <-> 6.28
# 11.7 <-> 6.28
# 6.5 <-> 6.69
# 4.1 <-> 5.6
# 11.7 <-> 15.22
# 9.3 <-> 12.13
# 38.5 <-> 29.45
# 8.5 <-> 9.06
# 5.5 <-> 5.98
# 16.0 <-> 16.96
# 11.5 <-> 10.51
# 9.7 <-> 8.67
# 7.0 <-> 8.77
# 19.0 <-> 20.95
# 10.5 <-> 12.37
# 30.0 <-> 30.44
# 7.7 <-> 8.6
# 27.83 <-> 19.92
# 30.65 <-> 26.12
# 7.3 <-> 7.71
# 15.0 <-> 13.26
# 3.7 <-> 5.24
# 16.0 <-> 17.75
# 6.5 <-> 6.28
# 16.5 <-> 16.46
# 12.1 <-> 10.98
# 9.5 <-> 9.15
# 29.5 <-> 27.73
# 11.0 <-> 7.77
# 6.5 <-> 8.77
# 6.0 <-> 6.23
# 12.5 <-> 8.67
# 15.7 <-> 14.55
# 24.0 <-> 25.58
# 7.0 <-> 6.28
# 6.0 <-> 8.01
# 7.7 <-> 7.71
# 4.9 <-> 5.21
# 4.5 <-> 6.28
# 8.5 <-> 10.65
# 12.1 <-> 13.58
# 6.9 <-> 6.28
# 5.7 <-> 6.28
# 4.0 <-> 5.21
# 14.0 <-> 11.84
# 6.1 <-> 6.28
# 6.5 <-> 8.01
# 4.5 <-> 5.21
# 10.5 <-> 9.13
# 12.1 <-> 12.2
# 7.7 <-> 8.98
# 5.3 <-> 5.21
# 6.5 <-> 8.66
# 19.0 <-> 18.32
# 4.9 <-> 5.21
# 5.3 <-> 6.42
# 8.5 <-> 9.21
# 5.0 <-> 5.21
# 6.0 <-> 7.71
# 7.0 <-> 9.15
# 7.0 <-> 6.28
# 5.5 <-> 6.28
# 22.0 <-> 18.32
# 10.5 <-> 10.51
# 4.1 <-> 5.21
# 4.5 <-> 6.28
# 5.7 <-> 9.57
# 16.9 <-> 13.41
# 7.0 <-> 8.18
# 3.5 <-> 5.21
# 14.1 <-> 10.88
# 8.1 <-> 8.67
# 14.5 <-> 14.25
# 20.0 <-> 30.15
# 8.9 <-> 9.59
# 6.1 <-> 6.9
# 9.3 <-> 9.89
# 8.1 <-> 6.9
# 6.5 <-> 5.26
# 9.7 <-> 12.13
# 7.0 <-> 7.85
# 7.0 <-> 7.71
# 4.5 <-> 6.28
# 6.9 <-> 7.57
# 6.9 <-> 8.66
# 9.7 <-> 8.66
# 4.9 <-> 6.26
# 4.9 <-> 6.9
# 8.9 <-> 8.59
# 6.5 <-> 10.41
# 4.5 <-> 5.21
# 9.0 <-> 7.71
# 8.5 <-> 9.78
# 6.1 <-> 7.71
# 4.5 <-> 5.21
# 8.5 <-> 10.65
# 4.0 <-> 6.28
# 19.0 <-> 11.86
# 7.3 <-> 6.9
# 15.0 <-> 16.3
# 4.1 <-> 5.21
# 8.1 <-> 9.13
# 9.4 <-> 10.88
# 11.7 <-> 11.0
# 4.1 <-> 6.28
# 15.0 <-> 11.96
# 10.5 <-> 8.01
# 9.5 <-> 9.15
# 25.0 <-> 19.19
# 16.9 <-> 13.58
# 7.3 <-> 7.71
# 11.3 <-> 13.56
# 4.1 <-> 6.08
# 7.7 <-> 6.93
# 6.0 <-> 9.15
# 4.1 <-> 5.21
# 12.5 <-> 14.93
# 12.0 <-> 13.26
# 17.0 <-> 6.08
# 6.9 <-> 8.6
# 4.9 <-> 5.21
# 18.5 <-> 15.02
# 10.0 <-> 7.77
# 8.9 <-> 9.78
# 18.1 <-> 20.55
# 7.7 <-> 7.71
# 9.3 <-> 6.28
# 10.5 <-> 11.85
# 16.5 <-> 12.23
# 5.7 <-> 6.82
# 33.47 <-> 29.58
# 5.5 <-> 6.28
# 31.0 <-> 30.44
# 6.5 <-> 6.28
# 17.0 <-> 17.15
# 9.0 <-> 12.93
# 18.0 <-> 15.7
# 6.9 <-> 7.73
# 7.3 <-> 7.16
# 4.1 <-> 5.21
# 4.5 <-> 5.21
# 5.0 <-> 6.28
# 4.5 <-> 5.21
# 15.3 <-> 17.89
# 3.5 <-> 5.21
# 25.5 <-> 16.38
# 8.1 <-> 9.13
# 6.5 <-> 6.19
# 11.5 <-> 11.86
# 4.1 <-> 5.21
# 4.5 <-> 6.28
# 5.5 <-> 5.21
# 6.1 <-> 6.9
# 6.0 <-> 5.21
# 5.0 <-> 5.21
# 7.5 <-> 6.85
# 12.1 <-> 9.8
# 6.0 <-> 7.77
# 19.7 <-> 21.58
# 10.9 <-> 9.77
# 4.5 <-> 5.98
# 6.5 <-> 10.41
# 5.3 <-> 5.26
# 8.1 <-> 7.71
# 16.9 <-> 18.59
# 6.9 <-> 6.28
# 11.0 <-> 8.01
# 7.3 <-> 7.85
# 12.9 <-> 9.92
# 4.5 <-> 5.21
# 6.9 <-> 5.24
# 6.5 <-> 6.82
# 8.5 <-> 8.59
# 7.3 <-> 9.57
# 6.1 <-> 6.9
# 4.5 <-> 5.21
# 13.7 <-> 12.13
